# %% [markdown]
# ## Instruction:
# For this coding test, your mission is to write an algorithm that plays the game of Hangman through our API server.
#
# When a user plays Hangman, the server first selects a secret word at random from a list. The server then returns a row of underscores (space separated)—one for each letter in the secret word—and asks the user to guess a letter. If the user guesses a letter that is in the word, the word is redisplayed with all instances of that letter shown in the correct positions, along with any letters correctly guessed on previous turns. If the letter does not appear in the word, the user is charged with an incorrect guess. The user keeps guessing letters until either (1) the user has correctly guessed all the letters in the word
# or (2) the user has made six incorrect guesses.
#
# You are required to write a "guess" function that takes current word (with underscores) as input and returns a guess letter. You will use the API codes below to play 1,000 Hangman games. You have the opportunity to practice before you want to start recording your game results.
#
# Your algorithm is permitted to use a training set of approximately 250,000 dictionary words. Your algorithm will be tested on an entirely disjoint set of 250,000 dictionary words. Please note that this means the words that you will ultimately be tested on do NOT appear in the dictionary that you are given. You are not permitted to use any dictionary other than the training dictionary we provided. This requirement will be strictly enforced by code review.
#
# You are provided with a basic, working algorithm. This algorithm will match the provided masked string (e.g. a _ _ l e) to all possible words in the dictionary, tabulate the frequency of letters appearing in these possible words, and then guess the letter with the highest frequency of appearence that has not already been guessed. If there are no remaining words that match then it will default back to the character frequency distribution of the entire dictionary.
#
# This benchmark strategy is successful approximately 18% of the time. Your task is to design an algorithm that significantly outperforms this benchmark.

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections
bigram_counts=None
try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode
from collections import defaultdict, Counter

class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)
def trigram_convert_word(word):
    return "$$" + word

# collect trigram counts
def trigram(corpus):
    trigram_counts = Counter()
    bigram_counts = defaultdict(Counter)
    
    for word in corpus:
        word = trigram_convert_word(word)
        
        # generate a list of trigrams
        trigram_list = zip(word[:-2], word[1:-1], word[2:])
        
        # generate a list of bigrams
        bigram_list = zip(word[:-1], word[1:])
        
        # iterate over trigrams
        for trigram in trigram_list:
            first, second, third = trigram
            element = first+second+third
            trigram_counts[element] += 1
            
        # iterate over bigrams
        for bigram in bigram_list:
            first, second = bigram
            bigram_counts[first][second] += 1
            
    return trigram_counts, bigram_counts

text_file = open("words_250000_train.txt","r")
full_dictionary = text_file.read().splitlines()
text_file.close()
training_set = full_dictionary

trigram_counts, bigram_counts_for_trigram = trigram(training_set)
unigram_counts = None

from collections import Counter

# Build unigram model. Count character frequency.
def unigram(corpus):
    unigram_counts = Counter()
    
    for word in corpus:
        for char in word:
            unigram_counts[char] += 1
            
    return unigram_counts

unigram_counts = unigram(training_set)
def bigram_prob(key, char, bigram_counts):
    prev_word_counts = bigram_counts[key]
    total_counts = float(sum(prev_word_counts.values()))

    return prev_word_counts[char] / float(sum(prev_word_counts.values()))
trigram_counts, bigram_counts_for_trigram = trigram(training_set)

def trigram_prob(wi_2, wi_1, char, trigram_counts, bigram_counts):
    # print(bigram_counts)
    # print(wi_2, wi_1, char)
    return trigram_counts[wi_2 + wi_1 + char] / float(bigram_counts[wi_2][wi_1])
def my_amazing_ai_guesser(mask, guessed, bigram_counts=bigram_counts_for_trigram, trigram_counts=trigram_counts, 
                          unigram_counts=unigram_counts):
    
    # available is a list that does not contain the character in guessed
    available = list(set(string.ascii_lowercase) - set(guessed))

    # The probabilities of available character
    trigram_probs = []
    
    # if len(mask) = 1, means that there is only a character. Therefore, need to pad in order to avoid error from 
    # traverse mask[index -2] and mask[index -1] 
    mask =["$","$"] +[ w for w in mask]
    
    trigram_lambda = 0.6
    bigram_lambda = 0.3
    unigram_lambda = 0.1
    
    for char in available:
        char_prob = 0
        for index in range(len(mask)):
            # The first case is that the first char has not been guessed
            if index == 0 and mask[index] == '_':
                char_prob += trigram_lambda * trigram_prob('$', '$', char, trigram_counts, bigram_counts)
                
            # The second case is that the second char has not been guessed
            if index == 1 and mask[index] == '_':
                # If the previous word has been guessed, apply trigram
                if not mask[index - 1] == '_':
                    char_prob += trigram_lambda * trigram_prob('$', mask[index - 1], char, trigram_counts, bigram_counts)
                    
                # If the previous word has not been guessed, apply unigram
                else:
                    char_prob +=  unigram_lambda * unigram_counts[char] / float(sum(unigram_counts.values()))
            
            # The third case is that the other chars have not been guessed
            elif mask[index] == '_':
                # If wi-2 and wi-1 have been guessed, apply trigram
                if not mask[index - 2] == '_' and not mask[index - 1] == '_':
                    char_prob += trigram_lambda * trigram_prob(mask[index - 2], mask[index - 1], char, 
                                                            trigram_counts, bigram_counts)
                    
                # If wi-2 hasn't been guessed but wi-1 has been guessed, apply bigram
                elif mask[index - 2] == '_' and not mask[index - 1] == '_':
                    char_prob += bigram_lambda * bigram_prob(mask[index - 1], char, bigram_counts)
                
                # If wi-1 hasn't been guessed, apply unigram
                else:
                    char_prob +=  unigram_lambda * unigram_counts[char] / float(sum(unigram_counts.values()))
                
            # The final case is that the character is guessed so we skip this position
            else:
                continue
                
        trigram_probs.append(char_prob)
    
    # Return the max probability of char
    return available[trigram_probs.index(max(trigram_probs))]

# %%
# ngram model:
def multi_dict(n, type):
    
trigramList=multi_dict(3,int)
bigramList=multi_dict(2,int)
unigramList=multi_dict(1,int)

def gettrigramProbability(word,char):
    if word[0]=='_':
        if word[1]=='_':
            return unigramList[char]/float(unigramList['$'])
        else:
            return bigramList[word[1]][char]/float(bigramList[word[1]]['$'])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-e551cccb0b02> in <module>
# ----> 1 print(trigram_counts['m']['e']['s'])
#       2 print(trigram_counts['j']['e']['s'])
#       3 print(trigram_counts['k']['e']['s'])
#       4 print(trigram_counts['d']['e']['s'])
#
# TypeError: 'int' object is not subscriptable

# %%
HANGMAN_URL = "https://www.trexsim.com/trexsim/hangman"

class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []
        
        full_dictionary_location = "words_250000_train.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)
        self.full_dictionary_common_letter_sorted = collections.Counter("".join(self.full_dictionary)).most_common()
        
        self.current_dictionary = []
    def _guess(self, word,letter): # word input example: "_ p p _ e "
        clean_word = word.replace("_",".")
        len_word = len(clean_word)
        current_dictionary = self.current_dictionary
        # print("current_dictionary:",current_dictionary)
        new_dictionary = []
        for dict_word in current_dictionary:
            if len(dict_word) != len_word:
                continue
            if re.match(clean_word,dict_word):
                new_dictionary.append(dict_word)
        self.current_dictionary = new_dictionary
        full_dict_string = "".join(new_dictionary)
        if len(full_dict_string) == 0:
            full_dict_string="".join(self.full_dictionary)
        c = collections.Counter(full_dict_string)
        sorted_letter_count = c.most_common()                   
        
        # print("current_dictionary:",c)
        # print("string:",full_dict_string)
        # return most frequently occurring letter in all possible words that hasn't been guessed yet
        return c[letter]/len(full_dict_string)
        for letter,instance_count in sorted_letter_count:
            if letter not in self.guessed_letters:
                return instance_count/float(len(full_dict_string))
            
        sorted_letter_count = self.full_dictionary_common_letter_sorted
        for letter,instance_count in sorted_letter_count:
            if letter not in self.guessed_letters:
                return instance_count/float(len(full_dict_string))

    def bigram_guesser(self,mask, guessed, bigram_counts=bigram_counts): # add extra arguments if needed 
        available = list(set(string.ascii_lowercase) - set(guessed))
        bigram_probs = []
        for char in available:
            char_prob = 0
            for index in range(len(mask)):
                # print("index:",index,"char:",char,"mask:",mask,"mask[index]:",mask[index])
                # print("char:",char,"index:",index,"mask[i]:",mask[index])
                if index == 0 and mask[index] == '_':
                    # char_prob +=  bigram_prob('$', char, bigram_counts)
                    char_prob +=  self._guess(mask,char)

                elif mask[index] == '_':
                    if not mask[index - 1] == '_':
                        char_prob +=  bigram_prob(mask[index - 1], char, bigram_counts)
                    else:
                        char_prob +=  self._guess(mask,char)
                else:
                    continue
            bigram_probs.append(char_prob)
        return available[bigram_probs.index(max(bigram_probs))]

    def trigram_guesser(self,mask, guessed, trigram_counts=trigram_counts):
        available = list(set(string.ascii_lowercase) - set(guessed))
        trigram_probs = []
        for char in available:
            char_prob = 0
            for index in range(len(mask)):
                if index == 0 and mask[index] == '_':
                    char_prob +=  self._guess(mask,char)
                elif index == 1 and mask[index] == '_':
                    if not mask[index - 1] == '_':
                        char_prob +=  bigram_prob(mask[index - 1],char,bigram_counts)
                    else:
                        char_prob +=  self._guess(mask,char)
                elif mask[index] == '_':
                    if not mask[index - 1] == '_':
                        if not mask[index - 2] == '_':
                            char_prob +=  trigram_prob(mask[index - 2], mask[index - 1], char, trigram_counts)
                        else:
                            char_prob +=  bigram_prob(mask[index - 1],char, bigram_counts)
                    else:
                        char_prob +=  self._guess(mask,char)
                else:
                    continue
            trigram_probs.append(char_prob)
        return available[trigram_probs.index(max(trigram_probs))]
    
    def guess(self, word):
        word = word[::2].replace("_","_")
        # print("clean_word:",clean_word)
        # return self.bigram_guesser(word, self.guessed_letters, bigram_counts=bigram_counts)
        # return self.trigram_guesser(word, self.guessed_letters, trigram_counts=trigram_counts)
        return my_amazing_ai_guesser(word, self.guessed_letters, bigram_counts=bigram_counts_for_trigram, trigram_counts=trigram_counts)

    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################
    
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary

    def offline(self,wordtobeguessed):
        tries_remains=6
        self.current_dictionary = self.full_dictionary
        # word is "_ " * len(wordtobeguessed)
        word = "_ " * len(wordtobeguessed)
        assert len(word) == len(wordtobeguessed) *2
        while tries_remains>0:
                # get guessed letter from user code
            guess_letter = self.guess(word)
            flag=False
            for index in range(len(wordtobeguessed)):
                if wordtobeguessed[index]==guess_letter:
                    print(word,index)
                    word=word[:2*index]+guess_letter+word[2*index+1:]
                    flag=True
            if flag==False:
                tries_remains-=1
                print("Wrong guess, you have",tries_remains,"tries left")
            if "_" not in word:
                print("You won!")
                break
            # append guessed letter to guessed letters field in hangman object
            self.guessed_letters.append(guess_letter)
            print("Guessing letter: {0}".format(guess_letter))
            print("Current word: {0}".format(word))
            # tries_remains -=1

    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary
                         
        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, word))
            while tries_remains>0:
                # get guessed letter from user code
                print("Word: {0}".format(word))
                guess_letter = self.guess(word)
                    
                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))
                    
                try:    
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                    print("-")
                except HangmanAPIError:
                    print('HangmanAPIError exception caught on request.')
                    continue
                except Exception as e:
                    print('Other exception caught on request.')
                    raise e
               
                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                if status=="success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status=="failed":
                    reason = res.get('reason', '# of tries exceeded!')
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    return False
                elif status=="ongoing":
                    word = res.get('word')
        else:
            if verbose:
                print("Failed to start a new game")
        return status=="success"
        
    def my_status(self):
        return self.request("/my_status", {})
    
    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        num_retry, time_sleep = 5, 2                                                                                        
        for it in range(num_retry):                                                                                         
            try:                                                                                                            
                response = self.session.request(                                                                            
                    method or "GET",                                                                                        
                    HANGMAN_URL + path,                                                                                     
                    timeout=self.timeout,                                                                                   
                    params=args,                                                                                            
                    data=post_args                                                                                          
                )                                                                                                           
                break                                                                                                       
            except requests.HTTPError as e:                                                                                 
                response = json.loads(e.read())                                                                             
                raise HangmanAPIError(response)                                                                             
            except requests.exceptions.SSLError as e:                                                                       
                if it + 1 == num_retry:                                                                                     
                    raise                                                                                                   
                time.sleep(time_sleep)  

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result

# %% [markdown]
# # API Usage Examples

# %% [markdown]
# ## To start a new game:
# 1. Make sure you have implemented your own "guess" method.
# 2. Use the access_token that we sent you to create your HangmanAPI object.
# 3. Start a game by calling "start_game" method.
# 4. If you wish to test your function without being recorded, set "practice" parameter to 1.
# 5. Note: You have a rate limit of 20 new games per minute. DO NOT start more than 20 new games within one minute.

# %%
api = HangmanAPI(access_token="1351d29da90b3d587ad0f8b1720f69", timeout=2000)
api.offline("desorption")
# Out:
# _ _ _ _ _ _ _ _ _ _  2
# Guessing letter: s
# Current word: _ _ s _ _ _ _ _ _ _
# _ _ s _ _ _ _ _ _ _  1
# Guessing letter: e
# Current word: _ e s _ _ _ _ _ _ _
# _ e s _ _ _ _ _ _ _  6
# Guessing letter: t
# Current word: _ e s _ _ _ t _ _ _
# _ e s _ _ _ t _ _ _  7
# Guessing letter: i
# Current word: _ e s _ _ _ t i _ _
# Wrong guess, you have 5 tries left
# Guessing letter: c
# Current word: _ e s _ _ _ t i _ _
# _ e s _ _ _ t i _ _  3
# _ e s o _ _ t i _ _  8
# Guessing letter: o
# Current word: _ e s o _ _ t i o _
# _ e s o _ _ t i o _  9
# Guessing letter: n
# Current word: _ e s o _ _ t i o n
# Wrong guess, you have 4 tries left
# Guessing letter: l
# Current word: _ e s o _ _ t i o n
# Wrong guess, you have 3 tries left
# Guessing letter: m
# Current word: _ e s o _ _ t i o n
# _ e s o _ _ t i o n  4
# Guessing letter: r
# Current word: _ e s o r _ t i o n
# Wrong guess, you have 2 tries left
# Guessing letter: a
# Current word: _ e s o r _ t i o n
# _ e s o r _ t i o n  5
# Guessing letter: p
# Current word: _ e s o r p t i o n
# Wrong guess, you have 1 tries left
# Guessing letter: u
# Current word: _ e s o r p t i o n
# Wrong guess, you have 0 tries left
# Guessing letter: b
# Current word: _ e s o r p t i o n

# %% [markdown]
# ## Playing practice games:
# You can use the command below to play up to 100,000 practice games.

# %%
[total_practice_runs_,total_recorded_runs,total_recorded_successes,total_practice_successes_] = api.my_status()
for _ in range(10):
    api.start_game(practice=1,verbose=True)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    practice_success_rate = total_practice_successes / total_practice_runs
    # print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))
print('success rate on last 10 games =',(total_practice_successes-total_practice_successes_)/10)
# Out:
# Successfully start a new game! Game ID: 55581ec37192. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Word: _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: s
# -
# Sever response: {'game_id': '55581ec37192', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ s _ '}
# Word: _ _ _ _ _ _ _ _ _ s _
# Guessing letter: e
# -
# Sever response: {'game_id': '55581ec37192', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ _ _ s _ '}
# Word: _ _ _ _ e _ _ _ _ s _
# Guessing letter: t
# -
# Sever response: {'game_id': '55581ec37192', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e t _ _ _ s _ '}
# Word: _ _ _ _ e t _ _ _ s _
# Guessing letter: i
# -
# Sever response: {'game_id': '55581ec37192', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e t i _ i s _ '}
# Word: _ _ _ _ e t i _ i s _
# Guessing letter: c
# -
# Sever response: {'game_id': '55581ec37192', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e t i c i s _ '}
# Word: _ _ _ _ e t i c i s _
# Guessing letter: m
# -
# Sever response: {'game_id': '55581ec37192', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e t i c i s m '}
# Word: _ _ _ _ e t i c i s m
# Guessing letter: a
# -
# Sever response: {'game_id': '55581ec37192', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e t i c i s m '}
# Word: _ _ _ _ e t i c i s m
# Guessing letter: p
# -
# Sever response: {'game_id': '55581ec37192', 'status': 'ongoing', 'tries_remains': 5, 'word': 'p _ _ _ e t i c i s m '}
# Word: p _ _ _ e t i c i s m
# Guessing letter: r
# -
# Sever response: {'game_id': '55581ec37192', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p _ _ _ e t i c i s m '}
# Word: p _ _ _ e t i c i s m
# Guessing letter: o
# -
# Sever response: {'game_id': '55581ec37192', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p _ o _ e t i c i s m '}
# Word: p _ o _ e t i c i s m
# Guessing letter: l
# -
# Sever response: {'game_id': '55581ec37192', 'status': 'ongoing', 'tries_remains': 3, 'word': 'p _ o _ e t i c i s m '}
# Word: p _ o _ e t i c i s m
# Guessing letter: n
# -
# Sever response: {'game_id': '55581ec37192', 'status': 'ongoing', 'tries_remains': 3, 'word': 'p _ o n e t i c i s m '}
# Word: p _ o n e t i c i s m
# Guessing letter: h
# -
# Sever response: {'game_id': '55581ec37192', 'status': 'success', 'tries_remains': 3, 'word': 'p h o n e t i c i s m '}
# Successfully finished game: 55581ec37192
# run 144 practice games out of an allotted 100,000. practice success rate so far = 0.146
# Successfully start a new game! Game ID: 3f6a92fcceac. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Word: _ _ _ _ _ _ _ _
# Guessing letter: s
# -
# Sever response: {'game_id': '3f6a92fcceac', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# Word: _ _ _ _ _ _ _ _
# Guessing letter: a
# -
# Sever response: {'game_id': '3f6a92fcceac', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ '}
# Word: _ _ _ _ _ _ _ _
# Guessing letter: e
# -
# Sever response: {'game_id': '3f6a92fcceac', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ _ _ _ _ '}
# Word: _ e _ _ _ _ _ _
# Guessing letter: r
# -
# Sever response: {'game_id': '3f6a92fcceac', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ _ _ _ _ '}
# Word: _ e _ _ _ _ _ _
# Guessing letter: n
# -
# Sever response: {'game_id': '3f6a92fcceac', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ n _ _ _ '}
# Word: _ e _ _ n _ _ _
# Guessing letter: t
# -
# Sever response: {'game_id': '3f6a92fcceac', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ _ n _ _ _ '}
# Word: _ e _ _ n _ _ _
# Guessing letter: d
# -
# Sever response: {'game_id': '3f6a92fcceac', 'status': 'ongoing', 'tries_remains': 2, 'word': 'd e _ _ n _ _ _ '}
# Word: d e _ _ n _ _ _
# Guessing letter: c
# -
# Sever response: {'game_id': '3f6a92fcceac', 'status': 'ongoing', 'tries_remains': 1, 'word': 'd e _ _ n _ _ _ '}
# Word: d e _ _ n _ _ _
# Guessing letter: i
# -
# Sever response: {'game_id': '3f6a92fcceac', 'status': 'failed', 'tries_remains': 0, 'word': 'd e _ _ n _ _ _ '}
# Failed game: 3f6a92fcceac. Because of: # of tries exceeded!
# run 145 practice games out of an allotted 100,000. practice success rate so far = 0.145
# Successfully start a new game! Game ID: c3a452afc9c4. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Word: _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: e
# -
# Sever response: {'game_id': 'c3a452afc9c4', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e _ _ _ _ _ _ _ e _ '}
# Word: _ _ e _ _ _ _ _ _ _ e _
# Guessing letter: s
# -
# Sever response: {'game_id': 'c3a452afc9c4', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ e _ _ _ _ _ _ _ e _ '}
# Word: _ _ e _ _ _ _ _ _ _ e _
# Guessing letter: r
# -
# Sever response: {'game_id': 'c3a452afc9c4', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r e _ _ r _ r r _ e _ '}
# Word: _ r e _ _ r _ r r _ e _
# Guessing letter: a
# -
# Sever response: {'game_id': 'c3a452afc9c4', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r e _ _ r _ r r _ e a '}
# Word: _ r e _ _ r _ r r _ e a
# Guessing letter: i
# -
# Sever response: {'game_id': 'c3a452afc9c4', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r e _ _ r _ r r _ e a '}
# Word: _ r e _ _ r _ r r _ e a
# Guessing letter: o
# -
# Sever response: {'game_id': 'c3a452afc9c4', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r e _ _ r o r r _ e a '}
# Word: _ r e _ _ r o r r _ e a
# Guessing letter: d
# -
# Sever response: {'game_id': 'c3a452afc9c4', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ r e _ _ r o r r _ e a '}
# Word: _ r e _ _ r o r r _ e a
# Guessing letter: c
# -
# Sever response: {'game_id': 'c3a452afc9c4', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ r e _ _ r o r r _ e a '}
# Word: _ r e _ _ r o r r _ e a
# Guessing letter: p
# -
# Sever response: {'game_id': 'c3a452afc9c4', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ r e _ _ r o r r _ e a '}
# Word: _ r e _ _ r o r r _ e a
# Guessing letter: h
# -
# Sever response: {'game_id': 'c3a452afc9c4', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ r e _ h r o r r h e a '}
# Word: _ r e _ h r o r r h e a
# Guessing letter: t
# -
# Sever response: {'game_id': 'c3a452afc9c4', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ r e t h r o r r h e a '}
# Word: _ r e t h r o r r h e a
# Guessing letter: m
# -
# Sever response: {'game_id': 'c3a452afc9c4', 'status': 'failed', 'tries_remains': 0, 'word': '_ r e t h r o r r h e a '}
# Failed game: c3a452afc9c4. Because of: # of tries exceeded!
# run 146 practice games out of an allotted 100,000. practice success rate so far = 0.144
# Successfully start a new game! Game ID: 5d6c0739f31e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: e
# -
# Sever response: {'game_id': '5d6c0739f31e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ _ _ _ _ _ _ e '}
# Word: _ _ _ _ e _ _ _ _ _ _ _ _ e
# Guessing letter: s
# -
# Sever response: {'game_id': '5d6c0739f31e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e s s _ _ _ _ _ _ e '}
# Word: _ _ _ _ e s s _ _ _ _ _ _ e
# Guessing letter: i
# -
# Sever response: {'game_id': '5d6c0739f31e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e s s i _ _ _ i _ e '}
# Word: _ _ _ _ e s s i _ _ _ i _ e
# Guessing letter: n
# -
# Sever response: {'game_id': '5d6c0739f31e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ n _ e s s i _ n _ i _ e '}
# Word: _ _ n _ e s s i _ n _ i _ e
# Guessing letter: t
# -
# Sever response: {'game_id': '5d6c0739f31e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ n _ e s s i _ n _ i _ e '}
# Word: _ _ n _ e s s i _ n _ i _ e
# Guessing letter: a
# -
# Sever response: {'game_id': '5d6c0739f31e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ n _ e s s i _ n a i _ e '}
# Word: _ _ n _ e s s i _ n a i _ e
# Guessing letter: l
# -
# Sever response: {'game_id': '5d6c0739f31e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ n _ e s s i _ n a i _ e '}
# Word: _ _ n _ e s s i _ n a i _ e
# Guessing letter: r
# -
# Sever response: {'game_id': '5d6c0739f31e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ n _ e s s i _ n a i r e '}
# Word: _ _ n _ e s s i _ n a i r e
# Guessing letter: o
# -
# Sever response: {'game_id': '5d6c0739f31e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ o n _ e s s i o n a i r e '}
# Word: _ o n _ e s s i o n a i r e
# Guessing letter: c
# -
# Sever response: {'game_id': '5d6c0739f31e', 'status': 'success', 'tries_remains': 4, 'word': 'c o n c e s s i o n a i r e '}
# Successfully finished game: 5d6c0739f31e
# run 147 practice games out of an allotted 100,000. practice success rate so far = 0.150
# Successfully start a new game! Game ID: 348bee69d63c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Word: _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: e
# -
# Sever response: {'game_id': '348bee69d63c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ '}
# Word: _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: s
# -
# Sever response: {'game_id': '348bee69d63c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ '}
# Word: _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: a
# -
# Sever response: {'game_id': '348bee69d63c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ a _ _ a _ _ _ _ '}
# Word: _ _ _ _ a _ _ a _ _ _ _
# Guessing letter: t
# -
# Sever response: {'game_id': '348bee69d63c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ a _ _ a _ t _ _ '}
# Word: _ _ _ _ a _ _ a _ t _ _
# Guessing letter: r
# -
# Sever response: {'game_id': '348bee69d63c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ a _ r a _ t _ _ '}
# Word: _ _ _ _ a _ r a _ t _ _
# Guessing letter: n
# -
# Sever response: {'game_id': '348bee69d63c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ n _ _ a _ r a n t _ _ '}
# Word: _ n _ _ a _ r a n t _ _
# Guessing letter: i
# -
# Sever response: {'game_id': '348bee69d63c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ n _ _ a _ r a n t _ _ '}
# Word: _ n _ _ a _ r a n t _ _
# Guessing letter: l
# -
# Sever response: {'game_id': '348bee69d63c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ n _ l a _ r a n t l _ '}
# Word: _ n _ l a _ r a n t l _
# Guessing letter: y
# -
# Sever response: {'game_id': '348bee69d63c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ n _ l a _ r a n t l y '}
# Word: _ n _ l a _ r a n t l y
# Guessing letter: c
# -
# Sever response: {'game_id': '348bee69d63c', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ n _ l a _ r a n t l y '}
# Word: _ n _ l a _ r a n t l y
# Guessing letter: g
# -
# Sever response: {'game_id': '348bee69d63c', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ n _ l a g r a n t l y '}
# Word: _ n _ l a g r a n t l y
# Guessing letter: p
# -
# Sever response: {'game_id': '348bee69d63c', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ n _ l a g r a n t l y '}
# Word: _ n _ l a g r a n t l y
# Guessing letter: d
# -
# Sever response: {'game_id': '348bee69d63c', 'status': 'failed', 'tries_remains': 0, 'word': '_ n _ l a g r a n t l y '}
# Failed game: 348bee69d63c. Because of: # of tries exceeded!
# run 148 practice games out of an allotted 100,000. practice success rate so far = 0.149
# Successfully start a new game! Game ID: 178b0fee5baa. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: e
# -
# Sever response: {'game_id': '178b0fee5baa', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ _ _ _ e _ e _ _ '}
# Word: _ _ _ _ _ e _ _ _ _ e _ e _ _
# Guessing letter: r
# -
# Sever response: {'game_id': '178b0fee5baa', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r _ _ r e _ _ _ _ e _ e _ _ '}
# Word: _ r _ _ r e _ _ _ _ e _ e _ _
# Guessing letter: s
# -
# Sever response: {'game_id': '178b0fee5baa', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r _ _ r e s s _ _ e _ e s s '}
# Word: _ r _ _ r e s s _ _ e _ e s s
# Guessing letter: i
# -
# Sever response: {'game_id': '178b0fee5baa', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r _ _ r e s s i _ e _ e s s '}
# Word: _ r _ _ r e s s i _ e _ e s s
# Guessing letter: n
# -
# Sever response: {'game_id': '178b0fee5baa', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r _ _ r e s s i _ e n e s s '}
# Word: _ r _ _ r e s s i _ e n e s s
# Guessing letter: a
# -
# Sever response: {'game_id': '178b0fee5baa', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r _ _ r e s s i _ e n e s s '}
# Word: _ r _ _ r e s s i _ e n e s s
# Guessing letter: o
# -
# Sever response: {'game_id': '178b0fee5baa', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r o _ r e s s i _ e n e s s '}
# Word: _ r o _ r e s s i _ e n e s s
# Guessing letter: p
# -
# Sever response: {'game_id': '178b0fee5baa', 'status': 'ongoing', 'tries_remains': 5, 'word': 'p r o _ r e s s i _ e n e s s '}
# Word: p r o _ r e s s i _ e n e s s
# Guessing letter: t
# -
# Sever response: {'game_id': '178b0fee5baa', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p r o _ r e s s i _ e n e s s '}
# Word: p r o _ r e s s i _ e n e s s
# Guessing letter: c
# -
# Sever response: {'game_id': '178b0fee5baa', 'status': 'ongoing', 'tries_remains': 3, 'word': 'p r o _ r e s s i _ e n e s s '}
# Word: p r o _ r e s s i _ e n e s s
# Guessing letter: m
# -
# Sever response: {'game_id': '178b0fee5baa', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p r o _ r e s s i _ e n e s s '}
# Word: p r o _ r e s s i _ e n e s s
# Guessing letter: u
# -
# Sever response: {'game_id': '178b0fee5baa', 'status': 'ongoing', 'tries_remains': 1, 'word': 'p r o _ r e s s i _ e n e s s '}
# Word: p r o _ r e s s i _ e n e s s
# Guessing letter: l
# -
# Sever response: {'game_id': '178b0fee5baa', 'status': 'failed', 'tries_remains': 0, 'word': 'p r o _ r e s s i _ e n e s s '}
# Failed game: 178b0fee5baa. Because of: # of tries exceeded!
# run 149 practice games out of an allotted 100,000. practice success rate so far = 0.148
# Successfully start a new game! Game ID: c4f661d92ea5. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: e
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ e _ _ _ _ _ _ _ _ '}
# Word: _ _ _ e _ e _ _ _ _ _ _ _ _
# Guessing letter: s
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ e _ _ _ _ _ _ _ _ '}
# Word: _ _ _ e _ e _ _ _ _ _ _ _ _
# Guessing letter: r
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ e _ e _ _ _ _ _ _ _ _ '}
# Word: _ _ _ e _ e _ _ _ _ _ _ _ _
# Guessing letter: n
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ e _ e n _ _ n _ _ n _ '}
# Word: _ _ _ e _ e n _ _ n _ _ n _
# Guessing letter: t
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ t e _ e n _ _ n _ _ n _ '}
# Word: _ _ t e _ e n _ _ n _ _ n _
# Guessing letter: d
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ t e d e n _ _ n _ _ n _ '}
# Word: _ _ t e d e n _ _ n _ _ n _
# Guessing letter: i
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ t e d e n _ _ n _ i n _ '}
# Word: _ _ t e d e n _ _ n _ i n _
# Guessing letter: g
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ t e d e n _ _ n _ i n g '}
# Word: _ _ t e d e n _ _ n _ i n g
# Guessing letter: c
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ t e d e n _ _ n c i n g '}
# Word: _ _ t e d e n _ _ n c i n g
# Guessing letter: a
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a t e d e n _ _ n c i n g '}
# Word: _ a t e d e n _ _ n c i n g
# Guessing letter: p
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a t e d e n _ _ n c i n g '}
# Word: _ a t e d e n _ _ n c i n g
# Guessing letter: o
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a t e d e n o _ n c i n g '}
# Word: _ a t e d e n o _ n c i n g
# Guessing letter: m
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a t e d e n o _ n c i n g '}
# Word: _ a t e d e n o _ n c i n g
# Guessing letter: u
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a t e d e n o u n c i n g '}
# Word: _ a t e d e n o u n c i n g
# Guessing letter: b
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a t e d e n o u n c i n g '}
# Word: _ a t e d e n o u n c i n g
# Guessing letter: h
# -
# Sever response: {'game_id': 'c4f661d92ea5', 'status': 'failed', 'tries_remains': 0, 'word': '_ a t e d e n o u n c i n g '}
# Failed game: c4f661d92ea5. Because of: # of tries exceeded!
# run 150 practice games out of an allotted 100,000. practice success rate so far = 0.147
# Successfully start a new game! Game ID: f2fc9e445949. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Word: _ _ _ _ _ _ _ _
# Guessing letter: s
# -
# Sever response: {'game_id': 'f2fc9e445949', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# Word: _ _ _ _ _ _ _ _
# Guessing letter: a
# -
# Sever response: {'game_id': 'f2fc9e445949', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ _ _ _ '}
# Word: _ a _ _ _ _ _ _
# Guessing letter: t
# -
# Sever response: {'game_id': 'f2fc9e445949', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ _ _ _ _ '}
# Word: _ a _ _ _ _ _ _
# Guessing letter: n
# -
# Sever response: {'game_id': 'f2fc9e445949', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a n _ _ _ _ _ '}
# Word: _ a n _ _ _ _ _
# Guessing letter: c
# -
# Sever response: {'game_id': 'f2fc9e445949', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a n _ _ _ _ _ '}
# Word: _ a n _ _ _ _ _
# Guessing letter: i
# -
# Sever response: {'game_id': 'f2fc9e445949', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a n _ _ _ _ _ '}
# Word: _ a n _ _ _ _ _
# Guessing letter: d
# -
# Sever response: {'game_id': 'f2fc9e445949', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a n d _ _ _ _ '}
# Word: _ a n d _ _ _ _
# Guessing letter: e
# -
# Sever response: {'game_id': 'f2fc9e445949', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a n d e _ e _ '}
# Word: _ a n d e _ e _
# Guessing letter: r
# -
# Sever response: {'game_id': 'f2fc9e445949', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a n d e r e r '}
# Word: _ a n d e r e r
# Guessing letter: p
# -
# Sever response: {'game_id': 'f2fc9e445949', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a n d e r e r '}
# Word: _ a n d e r e r
# Guessing letter: m
# -
# Sever response: {'game_id': 'f2fc9e445949', 'status': 'failed', 'tries_remains': 0, 'word': '_ a n d e r e r '}
# Failed game: f2fc9e445949. Because of: # of tries exceeded!
# run 151 practice games out of an allotted 100,000. practice success rate so far = 0.146
# Successfully start a new game! Game ID: 7268ded54bc3. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Word: _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: s
# -
# Sever response: {'game_id': '7268ded54bc3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ '}
# Word: _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: e
# -
# Sever response: {'game_id': '7268ded54bc3', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ e _ _ _ _ e _ _ _ '}
# Word: e _ e _ _ _ _ e _ _ _
# Guessing letter: n
# -
# Sever response: {'game_id': '7268ded54bc3', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ e _ _ _ _ e n _ _ '}
# Word: e _ e _ _ _ _ e n _ _
# Guessing letter: t
# -
# Sever response: {'game_id': '7268ded54bc3', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ e _ t _ _ e n t _ '}
# Word: e _ e _ t _ _ e n t _
# Guessing letter: i
# -
# Sever response: {'game_id': '7268ded54bc3', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ e _ t _ _ e n t _ '}
# Word: e _ e _ t _ _ e n t _
# Guessing letter: r
# -
# Sever response: {'game_id': '7268ded54bc3', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e _ e _ t _ _ e n t _ '}
# Word: e _ e _ t _ _ e n t _
# Guessing letter: a
# -
# Sever response: {'game_id': '7268ded54bc3', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e _ e _ t a _ e n t a '}
# Word: e _ e _ t a _ e n t a
# Guessing letter: l
# -
# Sever response: {'game_id': '7268ded54bc3', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e _ e _ t a _ e n t a '}
# Word: e _ e _ t a _ e n t a
# Guessing letter: x
# -
# Sever response: {'game_id': '7268ded54bc3', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e _ e _ t a _ e n t a '}
# Word: e _ e _ t a _ e n t a
# Guessing letter: m
# -
# Sever response: {'game_id': '7268ded54bc3', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e _ e _ t a m e n t a '}
# Word: e _ e _ t a m e n t a
# Guessing letter: p
# -
# Sever response: {'game_id': '7268ded54bc3', 'status': 'failed', 'tries_remains': 0, 'word': 'e _ e _ t a m e n t a '}
# Failed game: 7268ded54bc3. Because of: # of tries exceeded!
# run 152 practice games out of an allotted 100,000. practice success rate so far = 0.145
# Successfully start a new game! Game ID: 5aab40f412bf. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Word: _ _ _ _ _ _ _ _ _ _ _ _
# Guessing letter: e
# -
# Sever response: {'game_id': '5aab40f412bf', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e _ _ e _ _ _ _ _ _ '}
# Word: _ _ e _ _ e _ _ _ _ _ _
# Guessing letter: s
# -
# Sever response: {'game_id': '5aab40f412bf', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ e _ _ e _ _ _ _ _ _ '}
# Word: _ _ e _ _ e _ _ _ _ _ _
# Guessing letter: r
# -
# Sever response: {'game_id': '5aab40f412bf', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r e _ _ e r _ _ _ _ r '}
# Word: _ r e _ _ e r _ _ _ _ r
# Guessing letter: a
# -
# Sever response: {'game_id': '5aab40f412bf', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r e _ _ e r _ _ _ a r '}
# Word: _ r e _ _ e r _ _ _ a r
# Guessing letter: c
# -
# Sever response: {'game_id': '5aab40f412bf', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r e _ _ e r c _ _ a r '}
# Word: _ r e _ _ e r c _ _ a r
# Guessing letter: h
# -
# Sever response: {'game_id': '5aab40f412bf', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r e _ _ e r c _ _ a r '}
# Word: _ r e _ _ e r c _ _ a r
# Guessing letter: o
# -
# Sever response: {'game_id': '5aab40f412bf', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r e o _ e r c _ _ a r '}
# Word: _ r e o _ e r c _ _ a r
# Guessing letter: u
# -
# Sever response: {'game_id': '5aab40f412bf', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r e o _ e r c u _ a r '}
# Word: _ r e o _ e r c u _ a r
# Guessing letter: l
# -
# Sever response: {'game_id': '5aab40f412bf', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r e o _ e r c u l a r '}
# Word: _ r e o _ e r c u l a r
# Guessing letter: p
# -
# Sever response: {'game_id': '5aab40f412bf', 'status': 'success', 'tries_remains': 4, 'word': 'p r e o p e r c u l a r '}
# Successfully finished game: 5aab40f412bf
# run 153 practice games out of an allotted 100,000. practice success rate so far = 0.150
# 3
