# %% [markdown]
# # Trexquant Interview Project (The Hangman Game)
#
# * Copyright Trexquant Investment LP. All Rights Reserved.
# * Redistribution of this question without written consent from Trexquant is prohibited

# %% [markdown]
# ## Instruction:
# For this coding test, your mission is to write an algorithm that plays the game of Hangman through our API server.
#
# When a user plays Hangman, the server first selects a secret word at random from a list. The server then returns a row of underscores (space separated)—one for each letter in the secret word—and asks the user to guess a letter. If the user guesses a letter that is in the word, the word is redisplayed with all instances of that letter shown in the correct positions, along with any letters correctly guessed on previous turns. If the letter does not appear in the word, the user is charged with an incorrect guess. The user keeps guessing letters until either (1) the user has correctly guessed all the letters in the word
# or (2) the user has made six incorrect guesses.
#
# You are required to write a "guess" function that takes current word (with underscores) as input and returns a guess letter. You will use the API codes below to play 1,000 Hangman games. You have the opportunity to practice before you want to start recording your game results.
#
# Your algorithm is permitted to use a training set of approximately 250,000 dictionary words. Your algorithm will be tested on an entirely disjoint set of 250,000 dictionary words. Please note that this means the words that you will ultimately be tested on do NOT appear in the dictionary that you are given. You are not permitted to use any dictionary other than the training dictionary we provided. This requirement will be strictly enforced by code review.
#
# You are provided with a basic, working algorithm. This algorithm will match the provided masked string (e.g. a _ _ l e) to all possible words in the dictionary, tabulate the frequency of letters appearing in these possible words, and then guess the letter with the highest frequency of appearence that has not already been guessed. If there are no remaining words that match then it will default back to the character frequency distribution of the entire dictionary.
#
# This benchmark strategy is successful approximately 18% of the time. Your task is to design an algorithm that significantly outperforms this benchmark.

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections
try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

# %%
def getNGrams(words,n):
    ngrams = {}
    for word in words:
        # word="$"*(n-1)+word+"$"*(n-1)
        if len(word) <n:
            continue
        for i in range(len(word)-n+1):
            ngram = word[i:i+n]
            if ngram not in ngrams:
                ngrams[ngram] = 1
            else:
                ngrams[ngram]+=1
    return ngrams

# %%
word=["abc"]
# guessed=list(set(word)-set("_"))
print(getNGrams(word,1))
# Out:
# {'a': 1, 'b': 1, 'c': 1}

# %%
HANGMAN_URL = "https://www.trexsim.com/trexsim/hangman"

class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []
        
        # full_dictionary_location = "words_250000_train.txt"
        # self.full_dictionary = self.build_dictionary(full_dictionary_location)        
        # self.full_dictionary_common_letter_sorted = collections.Counter("".join(self.full_dictionary)).most_common()
        dictionary_file_location="words_250000_train.txt"
        text_file = open(dictionary_file_location,"r")
        words = text_file.read().splitlines()
        text_file.close()
        self.ngrams=[getNGrams(words,i) for i in range(1,6)]

        # self.current_dictionary = []
    def buildDict(self):
        dictionary_file_location="words_250000_train.txt"
        text_file = open(dictionary_file_location,"r")
        words = text_file.read().splitlines()
        text_file.close()
        
        self.ngrams=[getNGrams(words,i) for i in range(1,6)]
        
    def ngramprob(self,word,letter ):
        # print("________________________: word:",word,"letter:",letter)
        denominator=0
        underscroll_location=word.find("_")
        # if len(word)>2:
        #     print("word:",word,"letter:",letter)
        #     for l in string.ascii_lowercase:
        #         print("l:",l)
        #         print(self.ngrams[len(word)-1][word[:underscroll_location]+l+word[underscroll_location+1:]])

        for l in string.ascii_lowercase:
            
            try:
                denominator+=self.ngrams[len(word)-1][word[:underscroll_location]+l+word[underscroll_location+1:]]
            except:
                pass
        # print("____________:",word)
        # if len(word)>3:
        #     print("word with length >3:",word)
        # if word=="a_s":
        #     print("letter:",letter)
        #     print("denominator:",denominator)
        #     print("numerator:",self.ngrams[len(word)-1][word[:underscroll_location]+letter+word[underscroll_location+1:]])
        return self.ngrams[len(word)-1][word[:underscroll_location]+letter+word[underscroll_location+1:]]/denominator

        
    def guess(self, word): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        # clean_word = word[::2].replace("_",".")
        # guessed=list(set(word)-set("_"))
        word=word[::2]
        available = list(set(string.ascii_lowercase) - set(self.guessed_letters))
        probs=[]
        contributions=[0,0,0,0,0]
        for char in available:
            char_prob=0
            for i in range(len(word)):
                if word[i]!="_":
                    continue
                # find the longest continious string without any "_"

                # 4gram
                try:
                    if word[i-1]!="_" and word[i-2]!="_" and word[i-3]!="_":
                        contributions[3]+=self.ngramprob(word[i-3:i+1],char)
                        char_prob+=self.ngramprob(word[i-3:i+1],char)
                except:
                    pass
                try:
                    if word[i+1]!="_" and word[i-1]!="_" and word[i-2]!="_":
                        contributions[3]+=self.ngramprob(word[i-2:i+2],char)
                        char_prob+=self.ngramprob(word[i-2:i+2],char)
                except:
                    pass
                try:
                    if word[i+1]!="_" and word[i+2]!="_" and word[i-1]!="_":
                        contributions[3]+=self.ngramprob(word[i-1:i+3],char)
                        char_prob+=self.ngramprob(word[i-1:i+3],char)
                except:
                    pass
                try: 
                    if word[i+1]!="_" and word[i+2]!="_" and word[i+3]!="_":
                        contributions[3]+=self.ngramprob(word[i:i+4],char)
                        char_prob+=self.ngramprob(word[i:i+4],char) 
                except:
                    pass
                # 3gram
                try:
                    if word[i-1]!="_" and word[i-2]!="_":
                        contributions[2]+=self.ngramprob(word[i-2:i+1],char)
                        char_prob+=self.ngramprob(word[i-2:i+1],char)
                except:
                    pass
                try:
                    # a_b
                    if word[i+1]!="_" and word[i-1]!="_":
                        contributions[2]+=self.ngramprob(word[i-1:i+2],char)
                        char_prob+=self.ngramprob(word[i-1:i+2],char)
                except:
                    pass
                try:
                    if word[i+1]!="_" and word[i+2]!="_":
                        contributions[2]+=self.ngramprob(word[i:i+3],char)
                        char_prob+=self.ngramprob(word[i:i+3],char)
                except:
                    pass
                    # 2gram
                try:
                    if word[i-1]!="_":
                        contributions[1]+=self.ngramprob(word[i-1:i+1],char)
                        char_prob+=self.ngramprob(word[i-1:i+1],char)
                except:
                    pass
                try:
                    if word[i+1]!="_":
                        contributions[1]+=self.ngramprob(word[i:i+2],char)
                        char_prob+=self.ngramprob(word[i:i+2],char)
                except:
                    pass
                # 5 gram
                try:
                    if word[i-1]!="_" and word[i-2]!="_" and word[i-3]!="_" and word[i-4]!="_" :
                        contributions[4]+=self.ngramprob(word[i-4:i+1],char)
                        char_prob+=self.ngramprob(word[i-4:i+1],char)
                except:
                    pass
                try:
                    if word[i+1]!="_" and word[i-1]!="_" and word[i-2]!="_" and word[i-3]!="_" :
                        contributions[4]+=self.ngramprob(word[i-3:i+2],char)
                        char_prob+=self.ngramprob(word[i-3:i+2],char)
                except:
                    pass
                try:
                    if word[i+1]!="_" and word[i+2]!="_" and word[i-1]!="_" and word[i-2]!="_" :
                        contributions[4]+=self.ngramprob(word[i-2:i+3],char)
                        char_prob+=self.ngramprob(word[i-2:i+3],char)
                except:
                    pass
                try:
                    if word[i+1]!="_" and word[i+2]!="_" and word[i+3]!="_" and word[i-1]!="_" :
                        contributions[4]+=self.ngramprob(word[i-1:i+4],char)
                        char_prob+=self.ngramprob(word[i-1:i+4],char)
                except:
                    pass
                try:
                    if word[i+1]!="_" and word[i+2]!="_" and word[i+3]!="_" and word[i+4]!="_" :
                        contributions[4]+=self.ngramprob(word[i:i+5],char)
                        char_prob+=self.ngramprob(word[i:i+5],char)
                except:
                    pass
                

                # 1gram
                char_prob+=self.ngramprob(word[i:i+1],char)
                contributions[0]+=self.ngramprob(word[i:i+1],char)
            probs.append(char_prob)
        # create sorted dictionary of probabilities
        probs_dict=dict(zip(available,probs))
        probs_sorted=sorted(probs_dict.items(), key=lambda x: x[1], reverse=True)
        # iterate on probs_sorted
        for i in probs_sorted:
            # round the probability to 3 decimal places
            # i[1]=round()
            print(i[0],round(i[1],2),end=", ")
        # for i in range(len(probs)):
        #     # print upto 2 decimal places
        #     # probs[i]=round(probs[i],2)
        #     print(probs_sorted[i],round(probs_sorted[i],2),end=" ")
        print()
        print("contributions:",contributions)
        return available[probs.index(max(probs))]
            
    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################
    
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary
                
    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        # self.current_dictionary = self.full_dictionary
                         
        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, word))
            while tries_remains>0:
                # get guessed letter from user code
                guess_letter = self.guess(word)
                    
                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))
                    
                try:    
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                except HangmanAPIError:
                    print('HangmanAPIError exception caught on request.')
                    continue
                except Exception as e:
                    print('Other exception caught on request.')
                    raise e
               
                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                if status=="success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status=="failed":
                    reason = res.get('reason', '# of tries exceeded!')
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    return False
                elif status=="ongoing":
                    word = res.get('word')
        else:
            if verbose:
                print("Failed to start a new game")
        return status=="success"
        
    def my_status(self):
        return self.request("/my_status", {})
    def offline(self,wordtobeguessed):
        self.guessed_letters=[]
        tries_remains=6
        word = "_ " * len(wordtobeguessed)
        assert len(word) == len(wordtobeguessed) *2
        while tries_remains>0:
                # get guessed letter from user code
            guess_letter = self.guess(word)
            flag=False
            for index in range(len(wordtobeguessed)):
                if wordtobeguessed[index]==guess_letter:
                    word=word[:2*index]+guess_letter+word[2*index+1:]
                    flag=True
            if flag==False:
                tries_remains-=1
                print("Wrong guess, you have",tries_remains,"tries left")
            if "_" not in word:
                print("You won!")
                break
            # append guessed letter to guessed letters field in hangman object
            self.guessed_letters.append(guess_letter)
            # time.sleep(0.5)
            print("Guessed letter: {0}".format(guess_letter))
            print("Current word: {0}".format(word))
            
            # tries_remains -=1
    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        num_retry, time_sleep = 5, 2                                                                                        
        for it in range(num_retry):                                                                                         
            try:                                                                                                            
                response = self.session.request(                                                                            
                    method or "GET",                                                                                        
                    HANGMAN_URL + path,                                                                                     
                    timeout=self.timeout,                                                                                   
                    params=args,                                                                                            
                    data=post_args                                                                                          
                )                                                                                                           
                break                                                                                                       
            except requests.HTTPError as e:                                                                                 
                response = json.loads(e.read())                                                                             
                raise HangmanAPIError(response)                                                                             
            except requests.exceptions.SSLError as e:                                                                       
                if it + 1 == num_retry:                                                                                     
                    raise                                                                                                   
                time.sleep(time_sleep)  

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result
    
class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %% [markdown]
# # API Usage Examples

# %% [markdown]
# ## To start a new game:
# 1. Make sure you have implemented your own "guess" method.
# 2. Use the access_token that we sent you to create your HangmanAPI object.
# 3. Start a game by calling "start_game" method.
# 4. If you wish to test your function without being recorded, set "practice" parameter to 1.
# 5. Note: You have a rate limit of 20 new games per minute. DO NOT start more than 20 new games within one minute.

# %%
api = HangmanAPI(access_token="1351d29da90b3d587ad0f8b1720f69", timeout=2000)

# %%
api.offline("hangman")
# Out:
# e 0.77, i 0.61, a 0.59, n 0.5, o 0.49, r 0.49, s 0.49, t 0.45, l 0.4, c 0.29, u 0.25, d 0.25, p 0.22, m 0.2, h 0.19, g 0.17, y 0.14, b 0.13, f 0.09, v 0.07, k 0.06, w 0.06, z 0.03, x 0.02, q 0.01, j 0.01,
# contributions: [7.000000000000002, 0, 0, 0, 0]
# Wrong guess, you have 5 tries left
# Guessed letter: e
# Current word: _ _ _ _ _ _ _
# i 0.61, a 0.59, n 0.5, o 0.49, r 0.49, s 0.49, t 0.45, l 0.4, c 0.29, u 0.25, d 0.25, p 0.22, m 0.2, h 0.19, g 0.17, y 0.14, b 0.13, f 0.09, v 0.07, k 0.06, w 0.06, z 0.03, x 0.02, q 0.01, j 0.01,
# contributions: [6.229924423907606, 0, 0, 0, 0]
# Wrong guess, you have 4 tries left
# Guessed letter: i
# Current word: _ _ _ _ _ _ _
# a 0.59, n 0.5, o 0.49, r 0.49, s 0.49, t 0.45, l 0.4, c 0.29, u 0.25, d 0.25, p 0.22, m 0.2, h 0.19, g 0.17, y 0.14, b 0.13, f 0.09, v 0.07, k 0.06, w 0.06, z 0.03, x 0.02, q 0.01, j 0.01,
# contributions: [5.621276613769361, 0, 0, 0, 0]
# Guessed letter: a
# Current word: _ a _ _ _ a _
# r 0.84, n 0.79, t 0.75, l 0.75, s 0.54, c 0.49, o 0.38, m 0.38, p 0.32, d 0.31, h 0.27, u 0.26, b 0.25, g 0.24, y 0.14, v 0.12, f 0.11, w 0.1, k 0.09, z 0.05, x 0.03, j 0.02, q 0.01,
# contributions: [3.5920011144861554, 3.6337374395697273, 0, 0, 0]
# Wrong guess, you have 3 tries left
# Guessed letter: r
# Current word: _ a _ _ _ a _
# n 0.79, t 0.75, l 0.75, s 0.54, c 0.49, o 0.38, m 0.38, p 0.32, d 0.31, h 0.27, u 0.26, b 0.25, g 0.24, y 0.14, v 0.12, f 0.11, w 0.1, k 0.09, z 0.05, x 0.03, j 0.02, q 0.01,
# contributions: [3.240834433857035, 3.149793576979344, 0, 0, 0]
# Guessed letter: n
# Current word: _ a n _ _ a n
# t 0.82, l 0.56, c 0.54, m 0.51, s 0.48, d 0.42, g 0.41, o 0.39, h 0.34, p 0.28, u 0.19, b 0.19, y 0.12, v 0.12, f 0.11, k 0.1, w 0.1, z 0.05, j 0.03, x 0.03, q 0.01,
# contributions: [1.7295210815786926, 1.998444358811598, 2.063421674715878, 0, 0]
# Wrong guess, you have 2 tries left
# Guessed letter: t
# Current word: _ a n _ _ a n
# l 0.56, c 0.54, m 0.51, s 0.48, d 0.42, g 0.41, o 0.39, h 0.34, p 0.28, u 0.19, b 0.19, y 0.12, v 0.12, f 0.11, k 0.1, w 0.1, z 0.05, j 0.03, x 0.03, q 0.01,
# contributions: [1.53569509014254, 1.7221776539191942, 1.70877503804886, 0, 0]
# Wrong guess, you have 1 tries left
# Guessed letter: l
# Current word: _ a n _ _ a n
# c 0.54, m 0.51, s 0.48, d 0.42, g 0.41, o 0.39, h 0.34, p 0.28, u 0.19, b 0.19, y 0.12, v 0.12, f 0.11, k 0.1, w 0.1, z 0.05, j 0.03, x 0.03, q 0.01,
# contributions: [1.3628306630533722, 1.529374361681783, 1.519138179348052, 0, 0]
# Wrong guess, you have 0 tries left
# Guessed letter: c
# Current word: _ a n _ _ a n

# %%
# words=["ab","bc"]

# print(ngrams)

# %% [markdown]
# ## Playing practice games:
# You can use the command below to play up to 100,000 practice games.

# %%
[total_practice_runs_,total_recorded_runs,total_recorded_successes,total_practice_successes_] = api.my_status()
for _ in range(100):
    api.start_game(practice=1,verbose=True)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    practice_success_rate = total_practice_successes / total_practice_runs
    print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))
print(total_practice_successes-total_practice_successes_)
# Out:
# Successfully start a new game! Game ID: 82ee1333e8de. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# e 1.1, i 0.87, a 0.85, n 0.72, o 0.71, r 0.7, s 0.7, t 0.65, l 0.58, c 0.42, u 0.36, d 0.35, p 0.31, m 0.29, h 0.27, g 0.24, y 0.19, b 0.19, f 0.12, v 0.1, k 0.09, w 0.08, z 0.04, x 0.03, q 0.02, j 0.02,
# contributions: [10.000000000000002, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '82ee1333e8de', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ e _ _ '}
# r 0.94, n 0.85, i 0.83, a 0.83, s 0.83, t 0.75, l 0.69, o 0.66, d 0.49, c 0.46, u 0.35, m 0.35, p 0.35, h 0.3, g 0.27, b 0.21, y 0.19, v 0.15, f 0.14, k 0.11, w 0.1, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [8.009902830738353, 1.9488185499908899, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '82ee1333e8de', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ e _ _ '}
# n 0.85, i 0.83, a 0.83, s 0.83, t 0.75, l 0.69, o 0.66, d 0.49, c 0.46, u 0.35, m 0.35, p 0.35, h 0.3, g 0.27, b 0.21, y 0.19, v 0.15, f 0.14, k 0.11, w 0.1, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [7.377802805605937, 1.6429181161706796, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '82ee1333e8de', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ n _ n e _ _ '}
# o 2.02, i 1.92, a 1.27, s 1.19, t 0.84, g 0.65, d 0.62, u 0.59, l 0.55, c 0.42, m 0.29, p 0.28, h 0.23, y 0.2, b 0.16, f 0.12, k 0.11, w 0.11, v 0.1, x 0.06, z 0.03, q 0.02, j 0.02,
# contributions: [5.236672053977274, 3.0863180324820942, 2.542096142434219, 0.9423631123919309, 0]
# Guessing letter: o
# Sever response: {'game_id': '82ee1333e8de', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ n _ n e _ _ '}
# i 1.92, a 1.27, s 1.19, t 0.84, g 0.65, d 0.62, u 0.59, l 0.55, c 0.42, m 0.29, p 0.28, h 0.23, y 0.2, b 0.16, f 0.12, k 0.11, w 0.11, v 0.1, x 0.06, z 0.03, q 0.02, j 0.02,
# contributions: [4.742324023671535, 2.6081404829406236, 1.8373728136998873, 0.5984630163304515, 0]
# Guessing letter: i
# Sever response: {'game_id': '82ee1333e8de', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ i n _ n e _ _ '}
# g 2.08, a 1.29, s 1.26, t 1.16, d 0.79, l 0.72, u 0.5, c 0.48, m 0.39, p 0.33, h 0.3, y 0.2, b 0.19, k 0.19, f 0.17, v 0.15, w 0.14, x 0.07, z 0.07, q 0.02, j 0.02,
# contributions: [3.543151040171388, 2.398346402392298, 2.9222416210420006, 0.8766311169075218, 0.7643504531722055]
# Guessing letter: g
# Sever response: {'game_id': '82ee1333e8de', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ i n _ n e _ _ '}
# a 1.29, s 1.26, t 1.16, d 0.79, l 0.72, u 0.5, c 0.48, m 0.39, p 0.33, h 0.3, y 0.2, b 0.19, k 0.19, f 0.17, v 0.15, w 0.14, x 0.07, z 0.07, q 0.02, j 0.02,
# contributions: [3.3967335389735984, 2.204902254863248, 2.392310903769832, 0.3626285786406949, 0.07250755287009064]
# Guessing letter: a
# Sever response: {'game_id': '82ee1333e8de', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ a i n _ n e _ _ '}
# t 1.5, s 1.32, d 0.76, l 0.76, c 0.51, u 0.49, m 0.45, p 0.4, h 0.35, b 0.23, f 0.21, w 0.18, y 0.17, k 0.15, v 0.13, x 0.06, z 0.04, j 0.03, q 0.02,
# contributions: [2.407414815700323, 1.7863547509037268, 2.0764594599274475, 1.3883662058442672, 0.10740015271737327]
# Guessing letter: t
# Sever response: {'game_id': '82ee1333e8de', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ a i n t n e _ _ '}
# s 2.89, l 0.67, p 0.58, d 0.51, m 0.48, u 0.38, c 0.37, h 0.29, f 0.24, b 0.17, y 0.15, w 0.15, v 0.1, k 0.07, x 0.05, z 0.04, j 0.03, q 0.01,
# contributions: [1.6674971973120556, 1.0705742107207572, 1.2877132087055523, 1.3674840224338072, 1.7839285714285713]
# Guessing letter: s
# Sever response: {'game_id': '82ee1333e8de', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ a i n t n e s s '}
# p 0.47, l 0.44, m 0.36, u 0.25, d 0.23, h 0.22, c 0.21, f 0.19, b 0.11, w 0.09, v 0.06, k 0.05, y 0.05, z 0.02, j 0.02, x 0.01, q 0.0,
# contributions: [0.6940029537648263, 0.522463763719429, 0.4998827117053718, 0.4232424677187948, 0.6612244897959184]
# Guessing letter: p
# Sever response: {'game_id': '82ee1333e8de', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ a i n t n e s s '}
# l 0.44, m 0.36, u 0.25, d 0.23, h 0.22, c 0.21, f 0.19, b 0.11, w 0.09, v 0.06, k 0.05, y 0.05, z 0.02, j 0.02, x 0.01, q 0.0,
# contributions: [0.6320802580637873, 0.4780944175802841, 0.4478067088904527, 0.35437589670014347, 0.4204081632653061]
# Guessing letter: l
# Sever response: {'game_id': '82ee1333e8de', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ a i n t n e s s '}
# m 0.36, u 0.25, d 0.23, h 0.22, c 0.21, f 0.19, b 0.11, w 0.09, v 0.06, k 0.05, y 0.05, z 0.02, j 0.02, x 0.01, q 0.0,
# contributions: [0.516837306671009, 0.38566687497345603, 0.3563218390804597, 0.2560975609756098, 0.3755102040816326]
# Guessing letter: m
# Sever response: {'game_id': '82ee1333e8de', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ a i n t n e s s '}
# Failed game: 82ee1333e8de. Because of: # of tries exceeded!
# run 290 practice games out of an allotted 100,000. practice success rate so far = 0.252
# Successfully start a new game! Game ID: 677de5ed38f9. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# e 0.66, i 0.52, a 0.51, n 0.43, o 0.42, r 0.42, s 0.42, t 0.39, l 0.35, c 0.25, u 0.22, d 0.21, p 0.19, m 0.18, h 0.16, g 0.15, y 0.12, b 0.11, f 0.07, v 0.06, k 0.05, w 0.05, z 0.02, x 0.02, q 0.01, j 0.01,
# contributions: [5.999999999999995, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '677de5ed38f9', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ '}
# r 0.66, n 0.56, s 0.55, t 0.49, a 0.49, i 0.49, l 0.46, o 0.38, d 0.35, c 0.29, m 0.23, p 0.23, u 0.2, h 0.19, g 0.17, b 0.13, y 0.11, v 0.11, f 0.09, k 0.07, w 0.06, z 0.04, x 0.03, j 0.01, q 0.01,
# contributions: [4.449946017076864, 1.9488185499908899, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '677de5ed38f9', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e r '}
# t 0.58, i 0.42, n 0.41, s 0.37, l 0.37, a 0.36, o 0.29, p 0.28, d 0.28, c 0.24, h 0.23, m 0.21, v 0.2, g 0.16, u 0.16, b 0.14, f 0.09, y 0.09, k 0.09, w 0.06, z 0.04, x 0.02, j 0.01, q 0.01,
# contributions: [3.2790234691581945, 0.8659588998572045, 0.969181612038755, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '677de5ed38f9', 'status': 'ongoing', 'tries_remains': 6, 'word': 't _ _ _ e r '}
# i 0.56, a 0.37, n 0.35, s 0.33, l 0.33, o 0.32, h 0.28, p 0.25, d 0.24, c 0.2, v 0.19, m 0.18, u 0.16, g 0.14, b 0.13, y 0.1, f 0.08, k 0.08, w 0.06, z 0.04, x 0.01, j 0.01, q 0.01,
# contributions: [2.265441610432494, 1.4127364169450383, 0.7653061224489798, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '677de5ed38f9', 'status': 'ongoing', 'tries_remains': 5, 'word': 't _ _ _ e r '}
# a 0.37, n 0.35, s 0.33, l 0.33, o 0.32, h 0.28, p 0.25, d 0.24, c 0.2, v 0.19, m 0.18, u 0.16, g 0.14, b 0.13, y 0.1, f 0.08, k 0.08, w 0.06, z 0.04, x 0.01, j 0.01, q 0.01,
# contributions: [2.0045925489446743, 1.1545686391935464, 0.72910224695939, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': '677de5ed38f9', 'status': 'ongoing', 'tries_remains': 5, 'word': 't _ a _ e r '}
# l 0.64, n 0.57, c 0.45, h 0.44, s 0.43, m 0.42, p 0.41, d 0.39, v 0.35, g 0.3, o 0.28, k 0.26, b 0.24, u 0.21, y 0.16, f 0.12, w 0.12, z 0.07, x 0.03, j 0.02, q 0.01,
# contributions: [1.167116445918712, 2.399688303709248, 1.6421997370521049, 0.7009607686148921, 0]
# Guessing letter: l
# Sever response: {'game_id': '677de5ed38f9', 'status': 'ongoing', 'tries_remains': 5, 'word': 't _ a l e r '}
# h 1.05, c 0.45, u 0.4, v 0.4, p 0.32, n 0.3, d 0.3, s 0.29, o 0.25, g 0.25, m 0.25, b 0.15, f 0.13, w 0.13, y 0.1, k 0.05, z 0.03, j 0.01, x 0.01, q 0.0,
# contributions: [0.525936747262967, 0.8980635146839706, 0.9847723827667193, 1.2556810531021592, 1.205400485436893]
# Guessing letter: h
# Sever response: {'game_id': '677de5ed38f9', 'status': 'success', 'tries_remains': 5, 'word': 't h a l e r '}
# Successfully finished game: 677de5ed38f9
# run 291 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Successfully start a new game! Game ID: de328ce5a32d. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# e 1.1, i 0.87, a 0.85, n 0.72, o 0.71, r 0.7, s 0.7, t 0.65, l 0.58, c 0.42, u 0.36, d 0.35, p 0.31, m 0.29, h 0.27, g 0.24, y 0.19, b 0.19, f 0.12, v 0.1, k 0.09, w 0.08, z 0.04, x 0.03, q 0.02, j 0.02,
# contributions: [10.000000000000002, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': 'de328ce5a32d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# i 0.87, a 0.85, n 0.72, o 0.71, r 0.7, s 0.7, t 0.65, l 0.58, c 0.42, u 0.36, d 0.35, p 0.31, m 0.29, h 0.27, g 0.24, y 0.19, b 0.19, f 0.12, v 0.1, k 0.09, w 0.08, z 0.04, x 0.03, q 0.02, j 0.02,
# contributions: [8.899892034153732, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': 'de328ce5a32d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ i _ _ i _ _ '}
# n 1.13, t 0.98, s 0.91, a 0.86, r 0.85, l 0.79, o 0.74, c 0.63, d 0.5, m 0.41, p 0.36, u 0.33, h 0.32, g 0.3, b 0.24, f 0.19, v 0.19, y 0.16, k 0.12, w 0.1, z 0.1, x 0.04, j 0.02, q 0.02,
# contributions: [6.424316130022123, 3.867459835592449, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': 'de328ce5a32d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ i n _ i n _ '}
# t 2.24, g 1.87, d 1.4, s 1.08, a 0.97, l 0.91, r 0.89, c 0.88, o 0.81, k 0.5, m 0.49, h 0.41, f 0.4, p 0.38, u 0.35, v 0.33, b 0.23, w 0.2, y 0.2, z 0.11, x 0.05, j 0.03, q 0.02,
# contributions: [4.388277940045537, 3.2939646147951547, 4.36589331542346, 1.8267058778385104, 0.8932038834951456]
# Guessing letter: t
# Sever response: {'game_id': 'de328ce5a32d', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ i n _ i n _ '}
# g 1.87, d 1.4, s 1.08, a 0.97, l 0.91, r 0.89, c 0.88, o 0.81, k 0.5, m 0.49, h 0.41, f 0.4, p 0.38, u 0.35, v 0.33, b 0.23, w 0.2, y 0.2, z 0.11, x 0.05, j 0.03, q 0.02,
# contributions: [4.000625957173233, 2.731399607556131, 3.643586903924235, 1.441353787381364, 0.7111650485436892]
# Guessing letter: g
# Sever response: {'game_id': 'de328ce5a32d', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ i n g i n g '}
# r 0.9, l 0.68, s 0.54, a 0.43, d 0.34, o 0.33, h 0.31, m 0.31, p 0.27, c 0.26, k 0.18, u 0.18, w 0.16, y 0.14, b 0.14, z 0.13, v 0.13, f 0.11, x 0.03, j 0.01, q 0.01,
# contributions: [2.5694723039836287, 0.7259113444975266, 0.764360099066034, 0.7185214732083499, 0.7732558139534884]
# Guessing letter: r
# Sever response: {'game_id': 'de328ce5a32d', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ i n g i n g '}
# l 0.68, s 0.54, a 0.43, d 0.34, o 0.33, h 0.31, m 0.31, p 0.27, c 0.26, k 0.18, u 0.18, w 0.16, y 0.14, b 0.14, z 0.13, v 0.13, f 0.11, x 0.03, j 0.01, q 0.01,
# contributions: [2.288538959480332, 0.6081458376811267, 0.6691731566854653, 0.6140805743917032, 0.4709302325581396]
# Guessing letter: l
# Sever response: {'game_id': 'de328ce5a32d', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ l i n g i n g '}
# a 0.83, o 0.5, s 0.28, b 0.28, u 0.27, c 0.25, d 0.25, p 0.23, y 0.13, k 0.12, f 0.12, h 0.12, m 0.11, w 0.07, z 0.03, v 0.03, x 0.01, q 0.01, j 0.01,
# contributions: [1.543539792521083, 0.5941723046043637, 0.5473190575738742, 0.5191272315103429, 0.43195625759416767]
# Guessing letter: a
# Sever response: {'game_id': 'de328ce5a32d', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ l i n g i n g '}
# o 0.5, s 0.28, b 0.28, u 0.27, c 0.25, d 0.25, p 0.23, y 0.13, k 0.12, f 0.12, h 0.12, m 0.11, w 0.07, z 0.03, v 0.03, x 0.01, q 0.01, j 0.01,
# contributions: [1.2896219124544768, 0.39042790649386605, 0.3374766935985084, 0.4307169169736469, 0.35905224787363305]
# Guessing letter: o
# Sever response: {'game_id': 'de328ce5a32d', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ l i n g i n g '}
# s 0.28, b 0.28, u 0.27, c 0.25, d 0.25, p 0.23, y 0.13, k 0.12, f 0.12, h 0.12, m 0.11, w 0.07, z 0.03, v 0.03, x 0.01, q 0.01, j 0.01,
# contributions: [1.0777584708948738, 0.29698233350059694, 0.2376970450307927, 0.3663927458203457, 0.3244228432563791]
# Guessing letter: s
# Sever response: {'game_id': 'de328ce5a32d', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ l i n g i n g '}
# Failed game: de328ce5a32d. Because of: # of tries exceeded!
# run 292 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Successfully start a new game! Game ID: 81aa247531bb. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# e 0.88, i 0.7, a 0.68, n 0.57, o 0.56, r 0.56, s 0.56, t 0.52, l 0.46, c 0.34, u 0.29, d 0.28, p 0.25, m 0.23, h 0.22, g 0.2, y 0.15, b 0.15, f 0.1, v 0.08, k 0.07, w 0.07, z 0.03, x 0.02, q 0.02, j 0.01,
# contributions: [8.000000000000005, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '81aa247531bb', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ _ '}
# r 0.8, n 0.7, s 0.69, i 0.66, a 0.66, t 0.62, l 0.57, o 0.52, d 0.42, c 0.37, m 0.29, p 0.29, u 0.28, h 0.25, g 0.22, b 0.17, y 0.15, v 0.13, f 0.11, k 0.09, w 0.08, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [6.229924423907606, 1.9488185499908899, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '81aa247531bb', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e r _ _ '}
# i 0.88, t 0.79, a 0.77, s 0.71, o 0.65, n 0.61, l 0.53, d 0.4, c 0.39, p 0.38, m 0.35, h 0.3, u 0.27, g 0.25, v 0.25, b 0.22, y 0.19, f 0.15, k 0.12, w 0.09, z 0.05, x 0.02, j 0.02, q 0.01,
# contributions: [4.918535203737292, 1.6580917171017886, 1.830649896175865, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '81aa247531bb', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e r _ _ '}
# t 0.79, a 0.77, s 0.71, o 0.65, n 0.61, l 0.53, d 0.4, c 0.39, p 0.38, m 0.35, h 0.3, u 0.27, g 0.25, v 0.25, b 0.22, y 0.19, f 0.15, k 0.12, w 0.09, z 0.05, x 0.02, j 0.02, q 0.01,
# contributions: [4.39683708076165, 1.4685092982235295, 1.6605749996305124, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '81aa247531bb', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ e r _ _ '}
# a 0.77, s 0.71, o 0.65, n 0.61, l 0.53, d 0.4, c 0.39, p 0.38, m 0.35, h 0.3, u 0.27, g 0.25, v 0.25, b 0.22, y 0.19, f 0.15, k 0.12, w 0.09, z 0.05, x 0.02, j 0.02, q 0.01,
# contributions: [4.009185097889347, 1.3120384433422667, 1.4117452906244812, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': '81aa247531bb', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ e r _ _ '}
# s 0.71, o 0.65, n 0.61, l 0.53, d 0.4, c 0.39, p 0.38, m 0.35, h 0.3, u 0.27, g 0.25, v 0.25, b 0.22, y 0.19, f 0.15, k 0.12, w 0.09, z 0.05, x 0.02, j 0.02, q 0.01,
# contributions: [3.5013493377561358, 1.1473240186987654, 1.3142452576959665, 0, 0]
# Guessing letter: s
# Sever response: {'game_id': '81aa247531bb', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ e r _ _ '}
# o 0.65, n 0.61, l 0.53, d 0.4, c 0.39, p 0.38, m 0.35, h 0.3, u 0.27, g 0.25, v 0.25, b 0.22, y 0.19, f 0.15, k 0.12, w 0.09, z 0.05, x 0.02, j 0.02, q 0.01,
# contributions: [3.082112403082531, 1.0364888451757261, 1.1323174033117795, 0, 0]
# Guessing letter: o
# Sever response: {'game_id': '81aa247531bb', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ o _ _ e r o _ '}
# n 1.07, l 0.76, p 0.7, u 0.66, c 0.57, m 0.56, d 0.49, g 0.4, h 0.38, v 0.31, f 0.29, b 0.29, w 0.17, k 0.14, y 0.12, z 0.07, x 0.07, j 0.03, q 0.01,
# contributions: [1.7722570133088853, 2.5915847574976483, 1.394317710828507, 1.3184186888881357, 0]
# Guessing letter: n
# Sever response: {'game_id': '81aa247531bb', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o _ _ e r o _ '}
# l 0.76, p 0.7, u 0.66, c 0.57, m 0.56, d 0.49, g 0.4, h 0.38, v 0.31, f 0.29, b 0.29, w 0.17, k 0.14, y 0.12, z 0.07, x 0.07, j 0.03, q 0.01,
# contributions: [1.4856175749948466, 2.052894578270804, 1.2649334313865774, 1.2052856869479387, 0]
# Guessing letter: l
# Sever response: {'game_id': '81aa247531bb', 'status': 'failed', 'tries_remains': 0, 'word': '_ o _ _ e r o _ '}
# Failed game: 81aa247531bb. Because of: # of tries exceeded!
# run 293 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Successfully start a new game! Game ID: d3bacf944763. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# e 1.1, i 0.87, a 0.85, n 0.72, o 0.71, r 0.7, s 0.7, t 0.65, l 0.58, c 0.42, u 0.36, d 0.35, p 0.31, m 0.29, h 0.27, g 0.24, y 0.19, b 0.19, f 0.12, v 0.1, k 0.09, w 0.08, z 0.04, x 0.03, q 0.02, j 0.02,
# contributions: [10.000000000000002, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': 'd3bacf944763', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ _ _ e '}
# r 0.98, n 0.86, s 0.82, t 0.8, i 0.78, a 0.76, l 0.73, o 0.6, d 0.52, c 0.46, m 0.37, p 0.36, h 0.33, u 0.32, g 0.27, b 0.21, v 0.19, y 0.17, f 0.14, k 0.12, w 0.1, z 0.07, x 0.04, j 0.02, q 0.02,
# contributions: [7.119913627322975, 2.9247562523208432, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': 'd3bacf944763', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ r _ e _ _ _ _ e '}
# i 1.02, a 0.99, t 0.94, n 0.88, s 0.87, o 0.81, l 0.73, d 0.59, c 0.51, p 0.43, m 0.42, u 0.39, h 0.35, g 0.35, b 0.26, v 0.22, y 0.2, f 0.17, k 0.15, w 0.11, z 0.07, x 0.04, j 0.02, q 0.02,
# contributions: [5.738291071026841, 3.9927963755277136, 0.7863293864370289, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': 'd3bacf944763', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ r _ e _ _ _ _ e '}
# a 0.99, t 0.94, n 0.88, s 0.87, o 0.81, l 0.73, d 0.59, c 0.51, p 0.43, m 0.42, u 0.39, h 0.35, g 0.35, b 0.26, v 0.22, y 0.2, f 0.17, k 0.15, w 0.11, z 0.07, x 0.04, j 0.02, q 0.02,
# contributions: [5.129643260888595, 3.7172918592291775, 0.6553641908862575, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': 'd3bacf944763', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ r _ e _ a _ _ e '}
# t 1.19, n 1.11, l 0.99, s 0.92, o 0.75, c 0.66, d 0.66, m 0.61, p 0.52, g 0.44, h 0.41, u 0.39, b 0.35, v 0.27, y 0.2, f 0.2, k 0.16, w 0.16, z 0.08, x 0.07, j 0.03, q 0.02,
# contributions: [3.8890013206284397, 4.918623312040693, 1.3823318209006379, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': 'd3bacf944763', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ r _ e _ a _ _ e '}
# n 1.11, l 0.99, s 0.92, o 0.75, c 0.66, d 0.66, m 0.61, p 0.52, g 0.44, h 0.41, u 0.39, b 0.35, v 0.27, y 0.2, f 0.2, k 0.16, w 0.16, z 0.08, x 0.07, j 0.03, q 0.02,
# contributions: [3.5013493377561358, 4.2930605133366475, 1.20542763831549, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': 'd3bacf944763', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ r _ e _ a _ _ e '}
# l 0.99, s 0.92, o 0.75, c 0.66, d 0.66, m 0.61, p 0.52, g 0.44, h 0.41, u 0.39, b 0.35, v 0.27, y 0.2, f 0.2, k 0.16, w 0.16, z 0.08, x 0.07, j 0.03, q 0.02,
# contributions: [3.071390180285077, 3.7586022967994626, 1.0602066840351998, 0, 0]
# Guessing letter: l
# Sever response: {'game_id': 'd3bacf944763', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ r _ e _ a _ l e '}
# b 1.6, o 0.83, s 0.83, c 0.68, d 0.64, p 0.57, m 0.55, u 0.48, g 0.47, h 0.35, y 0.23, f 0.22, v 0.22, k 0.16, w 0.16, x 0.07, z 0.07, j 0.03, q 0.01,
# contributions: [2.271384438422287, 3.1500403502310195, 1.942271442091122, 0.8040236686390532, 0]
# Guessing letter: b
# Sever response: {'game_id': 'd3bacf944763', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ r _ e _ a b l e '}
# s 0.84, d 0.67, o 0.61, c 0.61, m 0.59, p 0.47, h 0.44, g 0.43, v 0.35, u 0.32, w 0.22, f 0.21, y 0.19, k 0.18, z 0.15, x 0.09, j 0.03, q 0.01,
# contributions: [1.7421056446276406, 2.2114997403734327, 1.265301950813914, 0.5930974573480008, 0.5999008954801262]
# Guessing letter: s
# Sever response: {'game_id': 'd3bacf944763', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ r _ e _ a b l e '}
# c 0.71, o 0.67, d 0.64, m 0.6, p 0.53, h 0.51, u 0.44, g 0.42, v 0.35, w 0.22, f 0.21, y 0.2, k 0.19, z 0.14, x 0.08, j 0.03, q 0.01,
# contributions: [1.0969607661339282, 2.297864132768219, 1.4942389330777774, 0.5301075357354588, 0.5319789048950555]
# Guessing letter: c
# Sever response: {'game_id': 'd3bacf944763', 'status': 'ongoing', 'tries_remains': 2, 'word': 's _ r _ e _ a b l e '}
# o 0.67, d 0.64, m 0.6, p 0.53, h 0.51, u 0.44, g 0.42, v 0.35, w 0.22, f 0.21, y 0.2, k 0.19, z 0.14, x 0.08, j 0.03, q 0.01,
# contributions: [0.9707805074112387, 2.0284558965997466, 1.2588411749225077, 0.4863233647322311, 0.4935294482001912]
# Guessing letter: o
# Sever response: {'game_id': 'd3bacf944763', 'status': 'ongoing', 'tries_remains': 1, 'word': 's _ r _ e _ a b l e '}
# d 0.64, m 0.6, p 0.53, h 0.51, u 0.44, g 0.42, v 0.35, w 0.22, f 0.21, y 0.2, k 0.19, z 0.14, x 0.08, j 0.03, q 0.01,
# contributions: [0.7589170658516357, 1.6769314788252787, 1.1500253272532537, 0.4854834991107305, 0.49252070576575946]
# Guessing letter: d
# Sever response: {'game_id': 'd3bacf944763', 'status': 'failed', 'tries_remains': 0, 'word': 's _ r _ e _ a b l e '}
# Failed game: d3bacf944763. Because of: # of tries exceeded!
# run 294 practice games out of an allotted 100,000. practice success rate so far = 0.252
# Successfully start a new game! Game ID: c86d291c2467. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# e 0.88, i 0.7, a 0.68, n 0.57, o 0.56, r 0.56, s 0.56, t 0.52, l 0.46, c 0.34, u 0.29, d 0.28, p 0.25, m 0.23, h 0.22, g 0.2, y 0.15, b 0.15, f 0.1, v 0.08, k 0.07, w 0.07, z 0.03, x 0.02, q 0.02, j 0.01,
# contributions: [8.000000000000005, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': 'c86d291c2467', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# i 0.7, a 0.68, n 0.57, o 0.56, r 0.56, s 0.56, t 0.52, l 0.46, c 0.34, u 0.29, d 0.28, p 0.25, m 0.23, h 0.22, g 0.2, y 0.15, b 0.15, f 0.1, v 0.08, k 0.07, w 0.07, z 0.03, x 0.02, q 0.02, j 0.01,
# contributions: [7.119913627322975, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': 'c86d291c2467', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ i _ _ _ '}
# n 0.78, t 0.69, a 0.68, s 0.66, r 0.64, o 0.58, l 0.57, c 0.44, d 0.35, m 0.29, u 0.28, p 0.27, h 0.24, g 0.22, b 0.17, y 0.14, f 0.13, v 0.12, k 0.09, w 0.08, z 0.06, x 0.03, q 0.01, j 0.01,
# contributions: [5.621276613769361, 1.9337299177962248, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': 'c86d291c2467', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ i _ n _ '}
# o 1.38, a 1.07, t 0.75, s 0.67, r 0.6, l 0.53, c 0.46, d 0.4, g 0.4, u 0.36, m 0.28, p 0.26, h 0.23, b 0.16, y 0.14, f 0.13, v 0.12, k 0.09, w 0.08, z 0.06, x 0.03, j 0.02, q 0.01,
# contributions: [4.388277940045537, 2.9501537518496237, 0.8944027250909654, 0, 0]
# Guessing letter: o
# Sever response: {'game_id': 'c86d291c2467', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ i o n _ '}
# t 1.97, s 1.08, a 1.0, r 0.59, l 0.52, d 0.43, c 0.4, g 0.38, h 0.25, p 0.24, m 0.24, u 0.22, b 0.17, f 0.14, y 0.13, v 0.13, k 0.08, w 0.07, z 0.04, x 0.03, j 0.02, q 0.01,
# contributions: [3.303792547438612, 1.5445456727787905, 1.6080700752045305, 1.682295176183461, 0]
# Guessing letter: t
# Sever response: {'game_id': 'c86d291c2467', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ i o n _ '}
# s 1.08, a 1.0, r 0.59, l 0.52, d 0.43, c 0.4, g 0.38, h 0.25, p 0.24, m 0.24, u 0.22, b 0.17, f 0.14, y 0.13, v 0.13, k 0.08, w 0.07, z 0.04, x 0.03, j 0.02, q 0.01,
# contributions: [2.980749228378356, 1.2632631691592784, 1.0105286731249026, 0.9131993116490977, 0]
# Guessing letter: s
# Sever response: {'game_id': 'c86d291c2467', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ i o n s '}
# r 0.5, l 0.45, a 0.37, d 0.26, c 0.25, h 0.21, m 0.19, p 0.18, u 0.16, g 0.16, b 0.14, v 0.09, y 0.08, f 0.08, k 0.06, w 0.05, x 0.03, z 0.03, j 0.01, q 0.01,
# contributions: [2.105108092920284, 0.671741129091391, 0.355773256300762, 0.10792117969463655, 0.06347438752783965]
# Guessing letter: r
# Sever response: {'game_id': 'c86d291c2467', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ i o n s '}
# l 0.45, a 0.37, d 0.26, c 0.25, h 0.21, m 0.19, p 0.18, u 0.16, g 0.16, b 0.14, v 0.09, y 0.08, f 0.08, k 0.06, w 0.05, x 0.03, z 0.03, j 0.01, q 0.01,
# contributions: [1.824174748416988, 0.5539756222749911, 0.27405174579251446, 0.0923920135717082, 0.05456570155902005]
# Guessing letter: l
# Sever response: {'game_id': 'c86d291c2467', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ l _ _ i o n s '}
# a 0.62, d 0.26, c 0.25, u 0.23, h 0.2, p 0.19, b 0.19, y 0.18, m 0.17, g 0.17, f 0.1, v 0.08, k 0.06, w 0.05, x 0.03, z 0.03, j 0.01, q 0.01,
# contributions: [1.1952666342235725, 1.3148670467328252, 0.22339445700410285, 0.06289964765757536, 0.027839643652561245]
# Guessing letter: a
# Sever response: {'game_id': 'c86d291c2467', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ l _ _ i o n s '}
# d 0.26, c 0.25, u 0.23, h 0.2, p 0.19, b 0.19, y 0.18, m 0.17, g 0.17, f 0.1, v 0.08, k 0.06, w 0.05, x 0.03, z 0.03, j 0.01, q 0.01,
# contributions: [0.9413487541569671, 0.9496128752866353, 0.22063133216109856, 0.06172517290878246, 0.027839643652561245]
# Guessing letter: d
# Sever response: {'game_id': 'c86d291c2467', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ l _ _ i o n s '}
# c 0.25, u 0.23, h 0.2, p 0.19, b 0.19, y 0.18, m 0.17, g 0.17, f 0.1, v 0.08, k 0.06, w 0.05, x 0.03, z 0.03, j 0.01, q 0.01,
# contributions: [0.8356570620676539, 0.8521331658607796, 0.17181612660135648, 0.05520031319326634, 0.026726057906458794]
# Guessing letter: c
# Sever response: {'game_id': 'c86d291c2467', 'status': 'failed', 'tries_remains': 0, 'word': '_ l _ _ i o n s '}
# Failed game: c86d291c2467. Because of: # of tries exceeded!
# run 295 practice games out of an allotted 100,000. practice success rate so far = 0.251
# Successfully start a new game! Game ID: 472ea9ef7aa8. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# e 0.88, i 0.7, a 0.68, n 0.57, o 0.56, r 0.56, s 0.56, t 0.52, l 0.46, c 0.34, u 0.29, d 0.28, p 0.25, m 0.23, h 0.22, g 0.2, y 0.15, b 0.15, f 0.1, v 0.08, k 0.07, w 0.07, z 0.03, x 0.02, q 0.02, j 0.01,
# contributions: [8.000000000000005, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '472ea9ef7aa8', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ '}
# r 0.8, n 0.7, s 0.69, i 0.66, a 0.66, t 0.62, l 0.57, o 0.52, d 0.42, c 0.37, m 0.29, p 0.29, u 0.28, h 0.25, g 0.22, b 0.17, y 0.15, v 0.13, f 0.11, k 0.09, w 0.08, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [6.229924423907606, 1.9488185499908899, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '472ea9ef7aa8', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ _ _ _ '}
# n 0.7, s 0.69, i 0.66, a 0.66, t 0.62, l 0.57, o 0.52, d 0.42, c 0.37, m 0.29, p 0.29, u 0.28, h 0.25, g 0.22, b 0.17, y 0.15, v 0.13, f 0.11, k 0.09, w 0.08, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [5.738291071026841, 1.6429181161706796, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '472ea9ef7aa8', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ e _ _ _ _ '}
# s 0.69, i 0.66, a 0.66, t 0.62, l 0.57, o 0.52, d 0.42, c 0.37, m 0.29, p 0.29, u 0.28, h 0.25, g 0.22, b 0.17, y 0.15, v 0.13, f 0.11, k 0.09, w 0.08, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [5.236672053977274, 1.4401217186984843, 0, 0, 0]
# Guessing letter: s
# Sever response: {'game_id': '472ea9ef7aa8', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ e _ _ _ s '}
# i 0.74, a 0.66, t 0.59, l 0.53, o 0.52, d 0.4, c 0.34, u 0.33, p 0.27, m 0.27, h 0.23, g 0.2, b 0.16, y 0.15, v 0.12, f 0.1, k 0.09, w 0.08, z 0.04, x 0.03, j 0.02, q 0.01,
# contributions: [4.06933911159263, 1.8035498463373505, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '472ea9ef7aa8', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ e _ i _ s '}
# t 0.87, l 0.78, a 0.73, o 0.58, d 0.57, c 0.53, m 0.46, p 0.38, u 0.35, h 0.25, g 0.25, v 0.2, b 0.19, f 0.16, y 0.14, k 0.12, w 0.1, z 0.07, x 0.06, j 0.02, q 0.01,
# contributions: [2.95636749051416, 2.9213061754803844, 0.9281511853338146, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '472ea9ef7aa8', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ e _ i _ s '}
# l 0.78, a 0.73, o 0.58, d 0.57, c 0.53, m 0.46, p 0.38, u 0.35, h 0.25, g 0.25, v 0.2, b 0.19, f 0.16, y 0.14, k 0.12, w 0.1, z 0.07, x 0.06, j 0.02, q 0.01,
# contributions: [2.6333241714539035, 2.4892855393163944, 0.8147795748540436, 0, 0]
# Guessing letter: l
# Sever response: {'game_id': '472ea9ef7aa8', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ e l i _ s '}
# a 0.94, o 0.85, c 0.73, d 0.56, u 0.46, p 0.46, m 0.44, h 0.36, g 0.35, v 0.28, b 0.28, k 0.27, f 0.17, z 0.16, y 0.14, w 0.13, q 0.03, x 0.02, j 0.01,
# contributions: [1.8761734343775684, 1.2862520564944788, 1.3651857539881012, 1.6555963807792113, 0.4727272727272727]
# Guessing letter: a
# Sever response: {'game_id': '472ea9ef7aa8', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ e l i a s '}
# m 0.95, d 0.63, c 0.61, h 0.59, v 0.56, b 0.5, g 0.45, p 0.4, o 0.26, k 0.19, u 0.16, w 0.15, y 0.13, f 0.12, z 0.1, x 0.02, j 0.02, q 0.01,
# contributions: [0.7688081304777135, 1.2669995036822137, 1.0685697372837566, 1.2539889136877211, 1.5026785714285715]
# Guessing letter: m
# Sever response: {'game_id': '472ea9ef7aa8', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a m e l i a s '}
# c 0.46, h 0.28, g 0.25, d 0.16, o 0.12, p 0.11, f 0.1, u 0.09, b 0.06, k 0.06, w 0.05, y 0.05, v 0.04, x 0.03, j 0.03, z 0.02, q 0.0,
# contributions: [0.3551342136895422, 0.39925737618386004, 0.40217937971500417, 0.3515936254980079, 0.3897058823529411]
# Guessing letter: c
# Sever response: {'game_id': '472ea9ef7aa8', 'status': 'success', 'tries_remains': 3, 'word': 'c a m e l i a s '}
# Successfully finished game: 472ea9ef7aa8
# run 296 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Successfully start a new game! Game ID: 6d9d8fd106b6. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# e 0.77, i 0.61, a 0.59, n 0.5, o 0.49, r 0.49, s 0.49, t 0.45, l 0.4, c 0.29, u 0.25, d 0.25, p 0.22, m 0.2, h 0.19, g 0.17, y 0.14, b 0.13, f 0.09, v 0.07, k 0.06, w 0.06, z 0.03, x 0.02, q 0.01, j 0.01,
# contributions: [7.000000000000002, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '6d9d8fd106b6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ '}
# r 0.73, n 0.63, s 0.62, a 0.57, i 0.57, t 0.56, l 0.51, o 0.45, d 0.39, c 0.33, m 0.26, p 0.26, u 0.24, h 0.22, g 0.19, b 0.15, y 0.13, v 0.12, f 0.1, k 0.08, w 0.07, z 0.04, x 0.03, j 0.02, q 0.01,
# contributions: [5.339935220492237, 1.9488185499908899, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '6d9d8fd106b6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e r '}
# t 0.64, i 0.51, n 0.48, a 0.44, s 0.44, l 0.43, o 0.36, d 0.31, p 0.31, c 0.28, h 0.26, m 0.23, v 0.21, u 0.2, g 0.19, b 0.16, y 0.11, f 0.11, k 0.1, w 0.07, z 0.05, x 0.02, j 0.01, q 0.01,
# contributions: [4.098779336447744, 0.8659588998572045, 0.969181612038755, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '6d9d8fd106b6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ t _ _ e r '}
# i 0.76, a 0.65, s 0.56, n 0.55, o 0.46, l 0.4, h 0.33, p 0.3, c 0.29, d 0.28, u 0.24, m 0.21, v 0.2, g 0.17, b 0.15, y 0.13, f 0.1, k 0.09, w 0.07, z 0.04, x 0.02, j 0.01, q 0.01,
# contributions: [3.0205888139099906, 2.249024842478315, 0.7653061224489798, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '6d9d8fd106b6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ t _ i e r '}
# h 1.07, l 0.83, a 0.66, s 0.65, n 0.54, o 0.44, p 0.33, c 0.3, d 0.29, f 0.29, m 0.23, u 0.22, g 0.17, z 0.16, w 0.16, b 0.14, k 0.13, y 0.13, v 0.12, x 0.03, j 0.01, q 0.01,
# contributions: [2.0045925489446743, 1.8721816958182331, 1.1700430029208573, 1.2334478813411358, 0.620253164556962]
# Guessing letter: h
# Sever response: {'game_id': '6d9d8fd106b6', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ t _ i e r '}
# l 0.83, a 0.66, s 0.65, n 0.54, o 0.44, p 0.33, c 0.3, d 0.29, f 0.29, m 0.23, u 0.22, g 0.17, z 0.16, w 0.16, b 0.14, k 0.13, y 0.13, v 0.12, x 0.03, j 0.01, q 0.01,
# contributions: [1.9226283988768542, 1.723414507457571, 0.9480855561787864, 0.8973504696605257, 0.3417721518987342]
# Guessing letter: l
# Sever response: {'game_id': '6d9d8fd106b6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ t _ i e r '}
# a 0.66, s 0.65, n 0.54, o 0.44, p 0.33, c 0.3, d 0.29, f 0.29, m 0.23, u 0.22, g 0.17, z 0.16, w 0.16, b 0.14, k 0.13, y 0.13, v 0.12, x 0.03, j 0.01, q 0.01,
# contributions: [1.7497639717876867, 1.5793317076364706, 0.8035491988622593, 0.6920493549228598, 0.17721518987341775]
# Guessing letter: a
# Sever response: {'game_id': '6d9d8fd106b6', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ t _ i e r '}
# s 0.65, n 0.54, o 0.44, p 0.33, c 0.3, d 0.29, f 0.29, m 0.23, u 0.22, g 0.17, z 0.16, w 0.16, b 0.14, k 0.13, y 0.13, v 0.12, x 0.03, j 0.01, q 0.01,
# contributions: [1.4958460917210812, 1.2653906314038803, 0.7155352530661588, 0.6899110797981272, 0.17721518987341775]
# Guessing letter: s
# Sever response: {'game_id': '6d9d8fd106b6', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ t s i e r '}
# n 0.81, u 0.6, o 0.6, c 0.16, p 0.09, d 0.09, f 0.08, g 0.06, m 0.06, y 0.05, b 0.04, k 0.02, v 0.02, w 0.02, x 0.01, z 0.01, q 0.0, j 0.0,
# contributions: [0.8574850829228526, 0.33835272279208206, 0.4310496912672743, 0.47126436781609193, 0.6363636363636364]
# Guessing letter: n
# Sever response: {'game_id': '6d9d8fd106b6', 'status': 'ongoing', 'tries_remains': 3, 'word': 'n _ t s i e r '}
# u 1.31, o 0.76, c 0.27, g 0.21, d 0.14, f 0.08, p 0.07, y 0.04, m 0.04, b 0.03, k 0.03, v 0.02, w 0.01, x 0.01, z 0.01, q 0.0, j 0.0,
# contributions: [0.35708268188291686, 0.6494787140991944, 0.4468843607139267, 0.6276525198938993, 0.9545454545454546]
# Guessing letter: u
# Sever response: {'game_id': '6d9d8fd106b6', 'status': 'success', 'tries_remains': 3, 'word': 'n u t s i e r '}
# Successfully finished game: 6d9d8fd106b6
# run 297 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Successfully start a new game! Game ID: ab7d86a7fda6. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# e 0.77, i 0.61, a 0.59, n 0.5, o 0.49, r 0.49, s 0.49, t 0.45, l 0.4, c 0.29, u 0.25, d 0.25, p 0.22, m 0.2, h 0.19, g 0.17, y 0.14, b 0.13, f 0.09, v 0.07, k 0.06, w 0.06, z 0.03, x 0.02, q 0.01, j 0.01,
# contributions: [7.000000000000002, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': 'ab7d86a7fda6', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# i 0.61, a 0.59, n 0.5, o 0.49, r 0.49, s 0.49, t 0.45, l 0.4, c 0.29, u 0.25, d 0.25, p 0.22, m 0.2, h 0.19, g 0.17, y 0.14, b 0.13, f 0.09, v 0.07, k 0.06, w 0.06, z 0.03, x 0.02, q 0.01, j 0.01,
# contributions: [6.229924423907606, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': 'ab7d86a7fda6', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i _ '}
# n 0.71, t 0.62, a 0.6, s 0.59, r 0.57, l 0.51, o 0.51, c 0.4, d 0.32, m 0.26, p 0.24, u 0.24, h 0.22, g 0.2, b 0.16, y 0.12, f 0.12, v 0.11, k 0.08, w 0.07, z 0.06, x 0.03, q 0.01, j 0.01,
# contributions: [4.8182370975165965, 1.9337299177962248, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': 'ab7d86a7fda6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ i _ '}
# t 0.62, a 0.6, s 0.59, r 0.57, l 0.51, o 0.51, c 0.4, d 0.32, m 0.26, p 0.24, u 0.24, h 0.22, g 0.2, b 0.16, y 0.12, f 0.12, v 0.11, k 0.08, w 0.07, z 0.06, x 0.03, q 0.01, j 0.01,
# contributions: [4.388277940045537, 1.6533493438447908, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': 'ab7d86a7fda6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ i t '}
# l 0.6, r 0.58, s 0.48, a 0.47, o 0.38, c 0.29, d 0.28, m 0.26, p 0.23, h 0.23, u 0.23, g 0.17, b 0.16, v 0.11, y 0.1, f 0.1, w 0.08, k 0.07, z 0.03, x 0.03, j 0.01, q 0.01,
# contributions: [3.3338549643110267, 0.7529174868720141, 0.8253945785264349, 0, 0]
# Guessing letter: l
# Sever response: {'game_id': 'ab7d86a7fda6', 'status': 'ongoing', 'tries_remains': 4, 'word': 'l _ _ _ _ i t '}
# a 0.52, r 0.51, s 0.43, o 0.42, d 0.27, c 0.26, m 0.24, u 0.23, p 0.21, h 0.2, y 0.18, g 0.15, b 0.15, v 0.11, f 0.1, w 0.08, k 0.07, z 0.03, x 0.02, j 0.01, q 0.01,
# contributions: [2.4365980686632662, 1.127565393051588, 0.625168093991082, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': 'ab7d86a7fda6', 'status': 'ongoing', 'tries_remains': 4, 'word': 'l a _ _ _ i t '}
# r 0.69, s 0.5, c 0.34, m 0.3, d 0.28, o 0.24, p 0.23, b 0.21, u 0.2, h 0.19, g 0.18, v 0.13, y 0.1, w 0.09, f 0.08, k 0.07, z 0.04, x 0.03, j 0.01, q 0.01,
# contributions: [1.5735306714308444, 1.1422847737410484, 1.2057801321267592, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': 'ab7d86a7fda6', 'status': 'ongoing', 'tries_remains': 3, 'word': 'l a _ _ _ i t '}
# s 0.5, c 0.34, m 0.3, d 0.28, o 0.24, p 0.23, b 0.21, u 0.2, h 0.19, g 0.18, v 0.13, y 0.1, w 0.09, f 0.08, k 0.07, z 0.04, x 0.03, j 0.01, q 0.01,
# contributions: [1.3628306630533722, 0.9068094138840476, 0.9601686245032435, 0, 0]
# Guessing letter: s
# Sever response: {'game_id': 'ab7d86a7fda6', 'status': 'ongoing', 'tries_remains': 3, 'word': 'l a _ s _ i t '}
# p 0.63, u 0.56, m 0.54, c 0.48, h 0.45, o 0.32, d 0.32, b 0.27, y 0.21, g 0.2, w 0.2, k 0.19, v 0.15, f 0.09, z 0.03, x 0.03, q 0.01, j 0.01,
# contributions: [0.7688081304777135, 1.4209388570920811, 1.5339296848067603, 0.9622994133841112, 0]
# Guessing letter: p
# Sever response: {'game_id': 'ab7d86a7fda6', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l a _ s _ i t '}
# u 0.56, m 0.54, c 0.48, h 0.45, o 0.32, d 0.32, b 0.27, y 0.21, g 0.2, w 0.2, k 0.19, v 0.15, f 0.09, z 0.03, x 0.03, q 0.01, j 0.01,
# contributions: [0.7068854347766744, 1.2847930105595071, 1.3352755706316235, 0.7308896461917824, 0]
# Guessing letter: u
# Sever response: {'game_id': 'ab7d86a7fda6', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l a _ s u i t '}
# y 0.67, w 0.57, d 0.32, o 0.26, m 0.25, b 0.22, c 0.21, g 0.16, k 0.12, h 0.08, f 0.07, v 0.05, x 0.03, z 0.02, q 0.0, j 0.0,
# contributions: [0.31706001564422287, 0.4422527224779767, 0.6645356474931157, 0.4338136077758718, 1.170056497175141]
# Guessing letter: y
# Sever response: {'game_id': 'ab7d86a7fda6', 'status': 'ongoing', 'tries_remains': 1, 'word': 'l a _ s u i t '}
# w 0.57, d 0.32, o 0.26, m 0.25, b 0.22, c 0.21, g 0.16, k 0.12, h 0.08, f 0.07, v 0.05, x 0.03, z 0.02, q 0.0, j 0.0,
# contributions: [0.29777065117430507, 0.41371548252315166, 0.5967009526941381, 0.3448923194206212, 0.7028248587570621]
# Guessing letter: w
# Sever response: {'game_id': 'ab7d86a7fda6', 'status': 'success', 'tries_remains': 1, 'word': 'l a w s u i t '}
# Successfully finished game: ab7d86a7fda6
# run 298 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Successfully start a new game! Game ID: 36f2905516fa. # of tries remaining: 6. Word: _ _ _ _ .
# e 0.44, i 0.35, a 0.34, n 0.29, o 0.28, r 0.28, s 0.28, t 0.26, l 0.23, c 0.17, u 0.15, d 0.14, p 0.12, m 0.12, h 0.11, g 0.1, y 0.08, b 0.08, f 0.05, v 0.04, k 0.04, w 0.03, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [3.9999999999999982, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '36f2905516fa', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ '}
# i 0.35, a 0.34, n 0.29, o 0.28, r 0.28, s 0.28, t 0.26, l 0.23, c 0.17, u 0.15, d 0.14, p 0.12, m 0.12, h 0.11, g 0.1, y 0.08, b 0.08, f 0.05, v 0.04, k 0.04, w 0.03, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [3.5599568136614903, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '36f2905516fa', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ i _ '}
# n 0.5, t 0.43, s 0.38, r 0.36, a 0.34, l 0.34, o 0.3, c 0.27, d 0.21, m 0.17, p 0.15, h 0.13, u 0.13, g 0.13, b 0.1, v 0.08, f 0.08, y 0.06, k 0.05, z 0.04, w 0.04, x 0.02, j 0.01, q 0.01,
# contributions: [2.4091185487582982, 1.9337299177962248, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '36f2905516fa', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ i _ '}
# t 0.43, s 0.38, r 0.36, a 0.34, l 0.34, o 0.3, c 0.27, d 0.21, m 0.17, p 0.15, h 0.13, u 0.13, g 0.13, b 0.1, v 0.08, f 0.08, y 0.06, k 0.05, z 0.04, w 0.04, x 0.02, j 0.01, q 0.01,
# contributions: [2.1941389700227694, 1.6533493438447908, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '36f2905516fa', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ t i _ '}
# a 0.76, s 0.6, o 0.53, c 0.51, r 0.27, l 0.25, u 0.16, p 0.15, d 0.14, v 0.13, m 0.11, g 0.09, f 0.08, h 0.08, b 0.07, y 0.06, z 0.05, k 0.03, w 0.02, x 0.02, q 0.01, j 0.0,
# contributions: [1.3335419857244108, 1.2970981650482538, 1.4601471585568135, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': '36f2905516fa', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ t i _ '}
# s 0.6, o 0.53, c 0.51, r 0.27, l 0.25, u 0.16, p 0.15, d 0.14, v 0.13, m 0.11, g 0.09, f 0.08, h 0.08, b 0.07, y 0.06, z 0.05, k 0.03, w 0.02, x 0.02, q 0.01, j 0.0,
# contributions: [1.1642633990133406, 1.0437135899752858, 1.1220320652402442, 0, 0]
# Guessing letter: s
# Sever response: {'game_id': '36f2905516fa', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ t i s '}
# o 0.22, r 0.22, c 0.18, u 0.14, l 0.12, p 0.11, h 0.05, y 0.05, d 0.04, m 0.03, g 0.03, f 0.03, b 0.02, k 0.01, x 0.01, w 0.01, v 0.01, z 0.0, q 0.0, j 0.0,
# contributions: [0.51225887706107, 0.28014434078507305, 0.2630238567843901, 0.2352238805970149, 0]
# Guessing letter: o
# Sever response: {'game_id': '36f2905516fa', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ t i s '}
# r 0.22, c 0.18, u 0.14, l 0.12, p 0.11, h 0.05, y 0.05, d 0.04, m 0.03, g 0.03, f 0.03, b 0.02, k 0.01, x 0.01, w 0.01, v 0.01, z 0.0, q 0.0, j 0.0,
# contributions: [0.44163772987453565, 0.21895953017234482, 0.2271825025279952, 0.1791044776119403, 0]
# Guessing letter: r
# Sever response: {'game_id': '36f2905516fa', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ t i s '}
# c 0.18, u 0.14, l 0.12, p 0.11, h 0.05, y 0.05, d 0.04, m 0.03, g 0.03, f 0.03, b 0.02, k 0.01, x 0.01, w 0.01, v 0.01, z 0.0, q 0.0, j 0.0,
# contributions: [0.3714043937487116, 0.1750012001728249, 0.18209055840605223, 0.11641791044776119, 0]
# Guessing letter: c
# Sever response: {'game_id': '36f2905516fa', 'status': 'failed', 'tries_remains': 0, 'word': '_ t i s '}
# Failed game: 36f2905516fa. Because of: # of tries exceeded!
# run 299 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Successfully start a new game! Game ID: 916592971e14. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# e 0.88, i 0.7, a 0.68, n 0.57, o 0.56, r 0.56, s 0.56, t 0.52, l 0.46, c 0.34, u 0.29, d 0.28, p 0.25, m 0.23, h 0.22, g 0.2, y 0.15, b 0.15, f 0.1, v 0.08, k 0.07, w 0.07, z 0.03, x 0.02, q 0.02, j 0.01,
# contributions: [8.000000000000005, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '916592971e14', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ _ '}
# r 0.8, n 0.7, s 0.69, i 0.66, a 0.66, t 0.62, l 0.57, o 0.52, d 0.42, c 0.37, m 0.29, p 0.29, u 0.28, h 0.25, g 0.22, b 0.17, y 0.15, v 0.13, f 0.11, k 0.09, w 0.08, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [6.229924423907606, 1.9488185499908899, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '916592971e14', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e _ _ '}
# n 0.7, s 0.69, i 0.66, a 0.66, t 0.62, l 0.57, o 0.52, d 0.42, c 0.37, m 0.29, p 0.29, u 0.28, h 0.25, g 0.22, b 0.17, y 0.15, v 0.13, f 0.11, k 0.09, w 0.08, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [5.738291071026841, 1.6429181161706796, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '916592971e14', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ e _ _ '}
# s 0.69, i 0.66, a 0.66, t 0.62, l 0.57, o 0.52, d 0.42, c 0.37, m 0.29, p 0.29, u 0.28, h 0.25, g 0.22, b 0.17, y 0.15, v 0.13, f 0.11, k 0.09, w 0.08, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [5.236672053977274, 1.4401217186984843, 0, 0, 0]
# Guessing letter: s
# Sever response: {'game_id': '916592971e14', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ e _ _ '}
# i 0.66, a 0.66, t 0.62, l 0.57, o 0.52, d 0.42, c 0.37, m 0.29, p 0.29, u 0.28, h 0.25, g 0.22, b 0.17, y 0.15, v 0.13, f 0.11, k 0.09, w 0.08, z 0.05, x 0.04, j 0.02, q 0.02,
# contributions: [4.747562296858068, 1.24328042080492, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '916592971e14', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ i _ e _ _ '}
# t 0.91, l 0.73, a 0.67, d 0.58, o 0.53, c 0.53, m 0.38, p 0.33, v 0.3, h 0.28, u 0.26, g 0.26, b 0.21, z 0.18, f 0.17, k 0.15, y 0.14, w 0.09, x 0.05, j 0.02, q 0.02,
# contributions: [3.5476409886169904, 2.526479856417882, 0.6953783198266871, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '916592971e14', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ i _ e _ _ '}
# l 0.73, a 0.67, d 0.58, o 0.53, c 0.53, m 0.38, p 0.33, v 0.3, h 0.28, u 0.26, g 0.26, b 0.21, z 0.18, f 0.17, k 0.15, y 0.14, w 0.09, x 0.05, j 0.02, q 0.02,
# contributions: [3.1599890057446824, 2.1224193879179825, 0.5756238465858943, 0, 0]
# Guessing letter: l
# Sever response: {'game_id': '916592971e14', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ l i _ e _ _ '}
# a 1.03, o 0.67, c 0.62, d 0.57, z 0.41, k 0.4, p 0.37, m 0.36, u 0.32, v 0.32, g 0.32, b 0.31, f 0.23, h 0.22, y 0.15, w 0.07, x 0.04, q 0.02, j 0.01,
# contributions: [2.34521679297196, 1.9257542773375431, 1.5597948891577456, 0.6198179979777552, 0]
# Guessing letter: a
# Sever response: {'game_id': '916592971e14', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a l i _ e _ a '}
# z 1.18, c 1.04, m 0.67, d 0.66, k 0.45, p 0.44, v 0.44, h 0.42, g 0.4, o 0.39, b 0.33, u 0.28, f 0.25, w 0.14, y 0.12, x 0.08, j 0.03, q 0.02,
# contributions: [1.15321219571657, 2.1368605191011625, 1.9767386743511717, 1.421726633150363, 0.6482122260668974]
# Guessing letter: z
# Sever response: {'game_id': '916592971e14', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a l i _ e _ a '}
# c 1.04, m 0.67, d 0.66, k 0.45, p 0.44, v 0.44, h 0.42, g 0.4, o 0.39, b 0.33, u 0.28, f 0.25, w 0.14, y 0.12, x 0.08, j 0.03, q 0.02,
# contributions: [1.1408591897572695, 2.0777926058815, 1.8054673181774321, 1.0349499209843018, 0.09342560553633217]
# Guessing letter: c
# Sever response: {'game_id': '916592971e14', 'status': 'failed', 'tries_remains': 0, 'word': '_ a l i _ e _ a '}
# Failed game: 916592971e14. Because of: # of tries exceeded!
# run 300 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Successfully start a new game! Game ID: 68682633a1fa. # of tries remaining: 6. Word: _ _ _ _ _ .
# e 0.55, i 0.43, a 0.42, n 0.36, o 0.35, r 0.35, s 0.35, t 0.32, l 0.29, c 0.21, u 0.18, d 0.18, p 0.15, m 0.15, h 0.14, g 0.12, y 0.1, b 0.09, f 0.06, v 0.05, k 0.04, w 0.04, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [4.999999999999999, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '68682633a1fa', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e '}
# r 0.39, i 0.38, t 0.37, n 0.37, a 0.35, s 0.34, l 0.33, o 0.29, c 0.21, d 0.2, p 0.17, m 0.17, h 0.16, u 0.16, g 0.13, b 0.1, v 0.09, y 0.08, f 0.06, k 0.06, w 0.05, z 0.03, x 0.01, j 0.01, q 0.01,
# contributions: [3.5599568136614903, 0.9759377023299537, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '68682633a1fa', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e '}
# i 0.38, t 0.37, n 0.37, a 0.35, s 0.34, l 0.33, o 0.29, c 0.21, d 0.2, p 0.17, m 0.17, h 0.16, u 0.16, g 0.13, b 0.1, v 0.09, y 0.08, f 0.06, k 0.06, w 0.05, z 0.03, x 0.01, j 0.01, q 0.01,
# contributions: [3.2790234691581945, 0.8659588998572045, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '68682633a1fa', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ e '}
# t 0.37, n 0.37, a 0.35, s 0.34, l 0.33, o 0.29, c 0.21, d 0.2, p 0.17, m 0.17, h 0.16, u 0.16, g 0.13, b 0.1, v 0.09, y 0.08, f 0.06, k 0.06, w 0.05, z 0.03, x 0.01, j 0.01, q 0.01,
# contributions: [2.9312247205077684, 0.8291470434327574, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '68682633a1fa', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ t _ e '}
# a 0.57, h 0.54, n 0.48, s 0.47, l 0.4, o 0.4, c 0.22, u 0.2, d 0.17, m 0.16, p 0.16, g 0.11, y 0.11, b 0.09, v 0.08, f 0.07, w 0.07, k 0.05, z 0.04, x 0.02, j 0.01, q 0.01,
# ...
# contributions: [5.389632454891074, 3.4497555529967463, 3.2850930224189625, 1.5081208285385503, 0.9125683060109291]
# Guessing letter: i
# Sever response: {'game_id': '41424dee3be3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ a _ _ _ _ _ r a i n e _ '}
# s 1.67, d 1.52, o 0.86, l 0.85, b 0.83, g 0.74, c 0.65, p 0.57, u 0.52, m 0.45, h 0.35, f 0.26, y 0.24, v 0.15, w 0.14, k 0.12, x 0.09, z 0.05, q 0.03, j 0.02,
# contributions: [4.095186907046767, 2.1083929956762337, 1.2930144301166882, 1.2687361878453038, 1.3395013252184154]
# Guessing letter: s
# Sever response: {'game_id': '41424dee3be3', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ a _ _ _ _ _ r a i n e _ '}
# d 1.5, l 0.86, o 0.85, b 0.82, c 0.76, g 0.72, p 0.66, u 0.56, m 0.52, h 0.52, f 0.25, y 0.23, w 0.17, v 0.14, k 0.14, x 0.09, z 0.05, q 0.03, j 0.02,
# contributions: [3.0941787865467187, 2.2694834482978443, 1.3782450983162626, 0.8692679558011047, 1.2821242760380875]
# Guessing letter: d
# Sever response: {'game_id': '41424dee3be3', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ a _ _ _ _ _ r a i n e d '}
# b 0.77, o 0.73, g 0.66, l 0.66, c 0.64, p 0.58, h 0.48, u 0.46, m 0.4, f 0.21, y 0.17, w 0.14, k 0.12, v 0.1, z 0.04, x 0.03, j 0.02, q 0.02,
# contributions: [2.4407698614328486, 1.7690916475156364, 0.9853220777138634, 0.4825, 0.5419161676646705]
# Guessing letter: b
# Sever response: {'game_id': '41424dee3be3', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ a _ _ _ _ b r a i n e d '}
# m 0.82, o 0.72, l 0.69, u 0.51, c 0.5, h 0.44, p 0.43, y 0.26, g 0.21, k 0.17, w 0.14, f 0.11, v 0.09, z 0.04, x 0.03, j 0.02, q 0.02,
# contributions: [1.9402225018896386, 1.671423800455949, 0.9010712092173977, 0.35907859078590787, 0.3229166666666667]
# Guessing letter: m
# Sever response: {'game_id': '41424dee3be3', 'status': 'ongoing', 'tries_remains': 4, 'word': 's _ a _ _ _ _ b r a i n e d '}
# o 0.72, l 0.69, u 0.51, c 0.5, h 0.44, p 0.43, y 0.26, g 0.21, k 0.17, w 0.14, f 0.11, v 0.09, z 0.04, x 0.03, j 0.02, q 0.02,
# contributions: [1.7938732441430656, 1.4243419022200434, 0.6666904547566292, 0.20596205962059622, 0.28125]
# Guessing letter: o
# Sever response: {'game_id': '41424dee3be3', 'status': 'ongoing', 'tries_remains': 4, 'word': 's _ a _ _ o _ b r a i n e d '}
# l 0.84, u 0.72, c 0.6, w 0.59, p 0.53, h 0.48, g 0.28, y 0.27, x 0.21, k 0.18, f 0.14, v 0.12, z 0.04, j 0.02, q 0.02,
# contributions: [1.1526140065683146, 2.0405962288638406, 0.8531063344050568, 0.41661777442516695, 0.5669642857142857]
# Guessing letter: l
# Sever response: {'game_id': '41424dee3be3', 'status': 'ongoing', 'tries_remains': 4, 'word': 's _ a l l o _ b r a i n e d '}
# w 3.41, c 1.53, u 0.94, h 0.88, p 0.74, g 0.67, y 0.26, x 0.24, v 0.2, k 0.18, f 0.17, q 0.04, z 0.03, j 0.02,
# contributions: [0.461064051891379, 1.0681351029827642, 1.7402482851052614, 2.3626906223350814, 3.662073365986721]
# Guessing letter: w
# Sever response: {'game_id': '41424dee3be3', 'status': 'ongoing', 'tries_remains': 4, 'word': 's _ a l l o w b r a i n e d '}
# c 1.22, h 0.81, p 0.31, u 0.27, g 0.25, v 0.12, f 0.11, k 0.07, y 0.06, z 0.02, j 0.01, x 0.01, q 0.01,
# contributions: [0.22218655782855923, 0.5663937692716434, 0.7820477867872445, 0.9319923294755628, 0.7622763608679101]
# Guessing letter: c
# Sever response: {'game_id': '41424dee3be3', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ a l l o w b r a i n e d '}
# h 0.81, p 0.31, u 0.27, g 0.25, v 0.12, f 0.11, k 0.07, y 0.06, z 0.02, j 0.01, x 0.01, q 0.01,
# contributions: [0.1801264715876627, 0.4351863229008702, 0.48731729673773944, 0.37285836587230486, 0.5645857124730363]
# Guessing letter: h
# Sever response: {'game_id': '41424dee3be3', 'status': 'success', 'tries_remains': 3, 'word': 's h a l l o w b r a i n e d '}
# Successfully finished game: 41424dee3be3
# run 386 practice games out of an allotted 100,000. practice success rate so far = 0.306
# Successfully start a new game! Game ID: 56e378fe5665. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# e 1.32, i 1.04, a 1.02, n 0.86, o 0.85, r 0.84, s 0.84, t 0.78, l 0.69, c 0.5, u 0.44, d 0.42, p 0.37, m 0.35, h 0.33, g 0.29, y 0.23, b 0.23, f 0.15, v 0.12, k 0.11, w 0.1, z 0.05, x 0.03, q 0.02, j 0.02,
# contributions: [12.000000000000009, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '56e378fe5665', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ '}
# i 1.04, a 1.02, n 0.86, o 0.85, r 0.84, s 0.84, t 0.78, l 0.69, c 0.5, u 0.44, d 0.42, p 0.37, m 0.35, h 0.33, g 0.29, y 0.23, b 0.23, f 0.15, v 0.12, k 0.11, w 0.1, z 0.05, x 0.03, q 0.02, j 0.02,
# contributions: [10.679870440984478, 0, 0, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '56e378fe5665', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ _ _ _ _ i _ _ i _ _ '}
# n 1.41, t 1.13, s 1.09, a 1.01, r 0.95, l 0.91, o 0.87, c 0.78, d 0.58, m 0.46, p 0.41, u 0.38, h 0.35, g 0.35, b 0.27, v 0.22, f 0.22, y 0.18, k 0.14, z 0.13, w 0.11, x 0.05, q 0.02, j 0.02,
# contributions: [7.227355646274894, 4.819571753806063, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '56e378fe5665', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n _ _ _ _ i _ n i _ _ '}
# o 2.29, a 1.85, t 1.08, s 1.06, g 1.04, c 0.81, r 0.76, l 0.67, d 0.57, u 0.52, m 0.39, p 0.33, h 0.27, f 0.22, b 0.21, v 0.18, y 0.17, z 0.16, k 0.14, w 0.1, x 0.03, q 0.02, j 0.02,
# contributions: [5.1196575967197955, 3.694933665429261, 3.1857115304353356, 0.8928571428571428, 0]
# Guessing letter: o
# Sever response: {'game_id': '56e378fe5665', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n _ _ _ _ i o n i _ _ '}
# t 2.81, s 2.01, a 1.02, c 0.96, g 0.85, r 0.73, l 0.69, d 0.62, z 0.36, m 0.33, h 0.32, p 0.32, u 0.31, b 0.23, f 0.22, v 0.16, y 0.13, k 0.11, w 0.08, x 0.05, q 0.02, j 0.02,
# contributions: [3.9645510569263323, 2.2232035766182925, 2.5241609383501995, 1.8045281667891513, 1.8088457907285616]
# Guessing letter: t
# Sever response: {'game_id': '56e378fe5665', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n t _ _ _ i o n i _ t '}
# s 4.02, a 1.36, r 0.95, c 0.89, l 0.69, h 0.48, d 0.43, z 0.36, u 0.33, p 0.29, m 0.28, g 0.24, f 0.2, b 0.19, y 0.14, v 0.13, k 0.07, w 0.07, x 0.05, j 0.01, q 0.01,
# contributions: [2.3845993827026857, 2.3334827579131594, 2.2264679254685733, 2.098288783510793, 2.156313515361143]
# Guessing letter: s
# Sever response: {'game_id': '56e378fe5665', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n t _ _ s i o n i s t '}
# a 0.76, r 0.71, u 0.53, l 0.28, h 0.27, y 0.22, p 0.12, c 0.1, d 0.09, m 0.09, g 0.06, b 0.06, w 0.04, f 0.04, k 0.03, v 0.02, z 0.02, x 0.01, j 0.01, q 0.0,
# contributions: [1.0525540464601413, 0.7504889182698784, 0.7728064202785606, 0.5982816896159794, 0.278436018957346]
# Guessing letter: a
# Sever response: {'game_id': '56e378fe5665', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i n t _ _ s i o n i s t '}
# r 0.71, u 0.53, l 0.28, h 0.27, y 0.22, p 0.12, c 0.1, d 0.09, m 0.09, g 0.06, b 0.06, w 0.04, f 0.04, k 0.03, v 0.02, z 0.02, x 0.01, j 0.01, q 0.0,
# contributions: [0.8832754597490706, 0.5656751209316273, 0.5049374041994379, 0.5004020943188805, 0.2381516587677725]
# Guessing letter: r
# Sever response: {'game_id': '56e378fe5665', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i n t r _ s i o n i s t '}
# u 2.21, y 0.36, l 0.16, d 0.12, p 0.11, m 0.08, c 0.08, g 0.05, b 0.05, k 0.05, h 0.04, f 0.02, v 0.02, w 0.02, z 0.01, x 0.0, q 0.0, j 0.0,
# contributions: [0.3714043937487116, 0.4498449417913928, 0.4672011956694687, 0.6056087067722085, 1.50000904001807]
# Guessing letter: u
# Sever response: {'game_id': '56e378fe5665', 'status': 'success', 'tries_remains': 4, 'word': 'i n t r u s i o n i s t '}
# Successfully finished game: 56e378fe5665
# run 387 practice games out of an allotted 100,000. practice success rate so far = 0.307
# Successfully start a new game! Game ID: 0d8c5d4f4074. # of tries remaining: 6. Word: _ _ _ _ _ .
# e 0.55, i 0.43, a 0.42, n 0.36, o 0.35, r 0.35, s 0.35, t 0.32, l 0.29, c 0.21, u 0.18, d 0.18, p 0.15, m 0.15, h 0.14, g 0.12, y 0.1, b 0.09, f 0.06, v 0.05, k 0.04, w 0.04, z 0.02, x 0.01, q 0.01, j 0.01,
# contributions: [4.999999999999999, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': '0d8c5d4f4074', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ '}
# r 0.59, n 0.49, s 0.48, t 0.43, a 0.4, l 0.4, i 0.4, d 0.32, o 0.31, c 0.25, m 0.2, p 0.19, u 0.17, h 0.17, g 0.14, b 0.11, v 0.1, y 0.09, f 0.08, k 0.06, w 0.06, z 0.03, x 0.03, j 0.01, q 0.01,
# contributions: [3.5599568136614903, 1.9488185499908899, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': '0d8c5d4f4074', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ '}
# n 0.49, s 0.48, t 0.43, a 0.4, l 0.4, i 0.4, d 0.32, o 0.31, c 0.25, m 0.2, p 0.19, u 0.17, h 0.17, g 0.14, b 0.11, v 0.1, y 0.09, f 0.08, k 0.06, w 0.06, z 0.03, x 0.03, j 0.01, q 0.01,
# contributions: [3.2790234691581945, 1.6429181161706796, 0, 0, 0]
# Guessing letter: n
# Sever response: {'game_id': '0d8c5d4f4074', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ e _ '}
# s 0.48, t 0.43, a 0.4, l 0.4, i 0.4, d 0.32, o 0.31, c 0.25, m 0.2, p 0.19, u 0.17, h 0.17, g 0.14, b 0.11, v 0.1, y 0.09, f 0.08, k 0.06, w 0.06, z 0.03, x 0.03, j 0.01, q 0.01,
# contributions: [2.9923840308441565, 1.4401217186984843, 0, 0, 0]
# Guessing letter: s
# Sever response: {'game_id': '0d8c5d4f4074', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ e _ '}
# t 0.43, a 0.4, l 0.4, i 0.4, d 0.32, o 0.31, c 0.25, m 0.2, p 0.19, u 0.17, h 0.17, g 0.14, b 0.11, v 0.1, y 0.09, f 0.08, k 0.06, w 0.06, z 0.03, x 0.03, j 0.01, q 0.01,
# contributions: [2.7128927410617543, 1.24328042080492, 0, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': '0d8c5d4f4074', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ e _ '}
# a 0.4, l 0.4, i 0.4, d 0.32, o 0.31, c 0.25, m 0.2, p 0.19, u 0.17, h 0.17, g 0.14, b 0.11, v 0.1, y 0.09, f 0.08, k 0.06, w 0.06, z 0.03, x 0.03, j 0.01, q 0.01,
# contributions: [2.4544580858135507, 1.0731004429685609, 0, 0, 0]
# Guessing letter: a
# Sever response: {'game_id': '0d8c5d4f4074', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ e _ '}
# l 0.4, i 0.4, d 0.32, o 0.31, c 0.25, m 0.2, p 0.19, u 0.17, h 0.17, g 0.14, b 0.11, v 0.1, y 0.09, f 0.08, k 0.06, w 0.06, z 0.03, x 0.03, j 0.01, q 0.01,
# contributions: [2.115900912391411, 1.007149873201346, 0, 0, 0]
# Guessing letter: l
# Sever response: {'game_id': '0d8c5d4f4074', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ l e _ '}
# i 0.44, o 0.4, d 0.4, b 0.36, c 0.29, p 0.24, u 0.24, g 0.18, m 0.17, y 0.12, h 0.12, f 0.1, v 0.06, k 0.06, w 0.05, x 0.04, z 0.02, q 0.01, j 0.01,
# contributions: [1.414061257204391, 0.8413738336444359, 1.0545882279622083, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': '0d8c5d4f4074', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ l e _ '}
# Failed game: 0d8c5d4f4074. Because of: # of tries exceeded!
# run 388 practice games out of an allotted 100,000. practice success rate so far = 0.307
# Successfully start a new game! Game ID: fc94133e7b59. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# e 1.21, i 0.96, a 0.93, n 0.79, o 0.78, r 0.77, s 0.77, t 0.71, l 0.63, c 0.46, u 0.4, d 0.39, p 0.34, m 0.32, h 0.3, g 0.27, y 0.21, b 0.21, f 0.14, v 0.11, k 0.1, w 0.09, z 0.05, x 0.03, q 0.02, j 0.02,
# contributions: [11.000000000000005, 0, 0, 0, 0]
# Guessing letter: e
# Sever response: {'game_id': 'fc94133e7b59', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ e _ _ '}
# r 1.01, i 0.92, n 0.92, a 0.91, s 0.9, t 0.82, l 0.74, o 0.73, d 0.53, c 0.5, u 0.39, p 0.38, m 0.38, h 0.33, g 0.29, b 0.22, y 0.21, v 0.16, f 0.15, k 0.11, w 0.11, z 0.06, x 0.05, j 0.02, q 0.02,
# contributions: [8.899892034153732, 1.9488185499908899, 0, 0, 0]
# Guessing letter: r
# Sever response: {'game_id': 'fc94133e7b59', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ e r _ '}
# i 1.14, a 1.02, t 0.99, s 0.92, o 0.86, n 0.83, l 0.7, c 0.51, d 0.5, p 0.48, m 0.44, h 0.38, u 0.38, g 0.33, v 0.28, b 0.27, y 0.24, f 0.18, k 0.15, w 0.12, z 0.06, x 0.03, j 0.03, q 0.02,
# contributions: [7.377802805605937, 1.6580917171017886, 1.830649896175865, 0, 0]
# Guessing letter: i
# Sever response: {'game_id': 'fc94133e7b59', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ i _ _ _ _ e r _ '}
# t 1.16, n 1.04, a 1.03, s 1.03, o 0.88, l 0.81, c 0.62, d 0.57, p 0.5, m 0.49, h 0.41, u 0.37, g 0.35, v 0.32, b 0.3, y 0.23, f 0.21, k 0.16, w 0.13, z 0.09, x 0.04, j 0.03, q 0.02,
# contributions: [5.8624494410155314, 3.257839326636769, 1.6605749996305124, 0, 0]
# Guessing letter: t
# Sever response: {'game_id': 'fc94133e7b59', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ t i _ _ t t e r _ '}
# a 2.31, o 1.54, s 1.44, n 1.29, u 0.83, c 0.81, l 0.54, m 0.4, p 0.35, d 0.32, y 0.29, b 0.26, g 0.24, h 0.22, v 0.21, f 0.21, w 0.1, k 0.08, z 0.07, x 0.03, j 0.02, q 0.02,
# contributions: [3.340987581574455, 2.890987948443871, 2.9098755521485336, 1.1907661782661783, 1.233876560332871]
# Guessing letter: a
# Sever response: {'game_id': 'fc94133e7b59', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ t i _ _ t t e r _ '}
# n 2.1, s 1.8, o 1.47, c 1.12, u 0.89, l 0.69, m 0.41, p 0.41, d 0.33, y 0.29, b 0.28, g 0.24, f 0.23, v 0.21, h 0.2, w 0.11, k 0.08, z 0.07, x 0.03, j 0.02, q 0.01,
# contributions: [2.334232891837424, 2.9928659764208305, 3.0218266646033385, 1.7289424626655396, 0.9062689623786407]
# Guessing letter: n
# Sever response: {'game_id': 'fc94133e7b59', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a n t i _ _ t t e r _ '}
# o 1.37, s 1.19, c 0.89, u 0.7, l 0.48, m 0.47, p 0.37, d 0.32, b 0.25, f 0.24, v 0.24, y 0.23, g 0.23, h 0.18, w 0.09, z 0.08, k 0.06, q 0.04, j 0.03, x 0.02,
# contributions: [1.53569509014254, 1.4009867431139118, 1.5900751818770034, 1.4089805437477498, 1.5496469139968705]
# Guessing letter: o
# Sever response: {'game_id': 'fc94133e7b59', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a n t i _ o t t e r _ '}
# c 2.53, s 1.51, l 1.36, p 1.21, m 1.17, d 1.04, g 0.75, b 0.52, f 0.45, h 0.38, v 0.34, y 0.22, u 0.15, z 0.15, w 0.14, k 0.08, j 0.05, x 0.05, q 0.04,
# contributions: [0.882554432388624, 1.3580906893224307, 2.181051102884302, 3.3080181490775815, 4.391824521648643]
# Guessing letter: c
# Sever response: {'game_id': 'fc94133e7b59', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a n t i _ o t t e r _ '}
# s 1.51, l 1.36, p 1.21, m 1.17, d 1.04, g 0.75, b 0.52, f 0.45, h 0.38, v 0.34, y 0.22, u 0.15, z 0.15, w 0.14, k 0.08, j 0.05, x 0.05, q 0.04,
# contributions: [0.798434259906831, 1.122980664914632, 1.747082333158652, 2.5436583088664073, 3.381403622348493]
# Guessing letter: s
# Sever response: {'game_id': 'fc94133e7b59', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a n t i _ o t t e r _ '}
# l 1.36, p 1.21, m 1.17, d 1.04, g 0.75, b 0.52, f 0.45, h 0.38, v 0.34, y 0.22, u 0.15, z 0.15, w 0.14, k 0.08, j 0.05, x 0.05, q 0.04,
# contributions: [0.6586886150156299, 0.9225214422834828, 1.40829382939603, 2.1723923541461456, 2.9213890011010197]
# Guessing letter: l
# Sever response: {'game_id': 'fc94133e7b59', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a n t i l o t t e r _ '}
# m 0.22, y 0.17, b 0.15, p 0.12, d 0.12, g 0.1, f 0.09, u 0.08, h 0.07, w 0.07, v 0.06, k 0.03, j 0.01, z 0.01, q 0.0, x 0.0,
# contributions: [0.2717228318114259, 0.2018014326584668, 0.25970978084818036, 0.24539776462853385, 0.32421875]
# Guessing letter: m
# Sever response: {'game_id': 'fc94133e7b59', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a n t i l o t t e r _ '}
# y 0.17, b 0.15, p 0.12, d 0.12, g 0.1, f 0.09, u 0.08, h 0.07, w 0.07, v 0.06, k 0.03, j 0.01, z 0.01, q 0.0, x 0.0,
# contributions: [0.24245298026211132, 0.172936071823164, 0.20209565993455195, 0.18754109138724523, 0.2734375]
# Guessing letter: y
# Sever response: {'game_id': 'fc94133e7b59', 'status': 'success', 'tries_remains': 3, 'word': 'a n t i l o t t e r y '}
# Successfully finished game: fc94133e7b59
# run 389 practice games out of an allotted 100,000. practice success rate so far = 0.308
# 47

# %% [markdown]
# ## Playing recorded games:
# Please finalize your code prior to running the cell below. Once this code executes once successfully your submission will be finalized. Our system will not allow you to rerun any additional games.
#
# Please note that it is expected that after you successfully run this block of code that subsequent runs will result in the error message "Your account has been deactivated".
#
# Once you've run this section of the code your submission is complete. Please send us your source code via email.

# %%
for i in range(1000):
    print('Playing ', i, ' th game')
    # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
    #api.start_game(practice=0,verbose=False)
    
    # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
    time.sleep(0.5)

# %% [markdown]
# ## To check your game statistics
# 1. Simply use "my_status" method.
# 2. Returns your total number of games, and number of wins.

# %%
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
success_rate = total_recorded_successes/total_recorded_runs
print('overall success rate = %.3f' % success_rate)
